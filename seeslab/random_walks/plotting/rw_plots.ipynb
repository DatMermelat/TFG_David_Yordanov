# %% [markdown]
# # Random Walk plotting

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Select the random walk path
# rw_path = "../rw_ng_test"
rw_path = "../rw_bms_test"

palette = sns.color_palette("husl", n_colors=10)

"""
Step || Expression || Steps without change || Change Distance|| Complexity || Norm
"""
# Out:
# '\nStep || Expression || Steps without change || Change Distance|| Complexity || Norm\n'

# %% [markdown]
# 1: Complexity vs Steps

# %%
plt.figure(figsize=(10, 6))
i=0
for filename in os.listdir(rw_path):
  if filename.startswith("rw") and filename.endswith(".txt"):

    x_values = []
    y_values = []

    with open(os.path.join(rw_path, filename), "r") as f:
      lines = f.readlines()

      for line in lines[1:]:
        data = line.strip().split(" || ")
        steps = int(data[0])
        complexity = int(data[4])
        x_values.append(steps)
        y_values.append(complexity)

    sns.regplot(x=x_values, y=y_values, scatter=True, color=palette[i], line_kws={"color": palette[i]}, scatter_kws={"s": 2, "alpha": 0.8}, label=f"Run {i}")
    i += 1
plt.title("Complexity vs Steps")
plt.xlabel("Steps")
plt.ylabel("Complexity")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 2: Change distance vs Steps

# %%
plt.figure(figsize=(10, 6))
i=0
for filename in os.listdir(rw_path):
  if filename.startswith("rw") and filename.endswith(".txt"):
    x_values = []
    y_values = []

    with open(os.path.join(rw_path, filename), "r") as f:
      lines = f.readlines()

      for line in lines[1:]:
        if not line.startswith(("best", "target")):
          data = line.strip().split(" || ")
          steps = int(data[0])
          chng_dists = float(data[3])
          x_values.append(steps)
          y_values.append(chng_dists)

    sns.regplot(x=x_values, y=y_values, scatter=True, color=palette[i], line_kws={"color": palette[i]}, scatter_kws={"s": 3, "alpha": 0.5}, label=f"Run {i}")
    i += 1

plt.title("Change Distance vs Steps")
plt.xlabel("Steps")
plt.ylabel("Change Distance")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 3: Change Distance vs Steps without change

# %%
plt.figure(figsize=(10, 6))
i=0
accumulated_data = []
for filename in os.listdir(rw_path):
  if filename.startswith("rw") and filename.endswith(".txt"):
    x_values = []
    y_values = []

    with open(os.path.join(rw_path, filename), "r") as f:
      lines = f.readlines()

      for line in lines[1:]:
        if not line.startswith(("best", "target")):
          data = line.strip().split(" || ")
          steps_no_chng = int(data[2])
          chng_dists = float(data[3])
          x_values.append(steps_no_chng)
          y_values.append(chng_dists)
          accumulated_data.append((steps_no_chng, chng_dists))

    sns.regplot(x=x_values, y=y_values, scatter=True, ci=None, color=palette[i], line_kws={"color": palette[i], "alpha": 0.3}, scatter_kws={"s": 5, "alpha": 0.7}, label=f"Run {i}")
    i += 1

plt.title("Change Distance vs Steps Without Change")
plt.xlabel("Steps Without Change")
plt.ylabel("Change Distance")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()

# %%
# Create a DataFrame for the total data
total_df = pd.DataFrame(accumulated_data, columns=['Steps Without Change', 'Change Distance'])

plt.figure(figsize=(10, 6))
sns.lineplot(data=total_df, x='Steps Without Change', y='Change Distance', label='Average Change Distance', linewidth=2)
plt.title("Average Change Distance vs Steps Without Change")
plt.xlabel("Steps Without Change")
plt.ylabel("Average Change Distance")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 4: Norm vs Steps

# %%
plt.figure(figsize=(10, 6))
i=0
for filename in os.listdir(rw_path):
  if filename.startswith("rw") and filename.endswith(".txt"):
    x_values = []
    y_values = []

    with open(os.path.join(rw_path, filename), "r") as f:
      lines = f.readlines()

      for line in lines[1:]:
        if not line.startswith(("best", "target")):
          data = line.strip().split(" || ")
          steps = int(data[0])
          norms = float(data[5])
          x_values.append(steps)
          y_values.append(norms)

    sns.lineplot(x=x_values, y=y_values, alpha = 0.6, linewidth=2, color=palette[i], label=f"Run {i}")
    i += 1

plt.title("Norm vs Steps")
plt.xlabel("Steps")
plt.ylabel("Norm")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 5: Unique Expressions vs Steps

# %%
plt.figure(figsize=(10, 6))
i=0
expressions = {}
for filename in os.listdir(rw_path):
  if filename.startswith("rw") and filename.endswith(".txt"):
    x_values = []
    y_values = []
    n_uniq = 0

    with open(os.path.join(rw_path, filename), "r") as f:
      lines = f.readlines()

      for line in lines[1:]:
        if not line.startswith(("best", "target")):
          data = line.strip().split(" || ")
          steps = int(data[0])
          expr = str(data[1])
          expr_visits = int(data[2])
          x_values.append(steps)

          if expr not in expressions:
            expressions[expr] = 0
            n_uniq += 1
          expressions[expr] += 1 + expr_visits

          y_values.append(n_uniq)

    sns.lineplot(x=x_values, y=y_values, color=palette[i], label=f"Run {i}", linewidth=2, alpha=0.7)
    i += 1

plt.title("Unique Expressions vs Steps")
plt.xlabel("Steps")
plt.ylabel("Unique Expressions")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 6: Visits Distribution

# %%
import numpy as np
plt.figure(figsize=(10, 6))
sns.histplot(list(expressions.values()), bins=np.logspace(0, 3.5, 15), kde=True, stat="probability")
plt.title("Expression Frequency Distribution")
plt.xlabel("Number of Occurrences")
plt.ylabel("Frequency")
plt.xscale("log")
plt.grid(which="both", linestyle="--", linewidth=0.5, alpha=0.7)
plt.show()

# %%
print("Expressions || Visits")
for expr, count in sorted(expressions.items(), key=lambda x: x[1], reverse=True):
    print(f"{expr} || {count}")
# Out:
# Expressions || Visits
# 3 || 2005
# C*X || 829
# log(4) || 747
# sqrt(5-5) || 696
# log(cos(C)) || 672
# C*exp(C) || 661
# log(C^3-C) || 653
# sqrt(X-C) || 603
# log(X-C) || 595
# log(C-C) || 560
# log(C-log(C)) || 451
# log((C^5)^5) || 449
# log(cos(C/C)) || 363
# 3*X || 362
# log(2) || 334
# C^5*C || 316
# sqrt(5-C) || 306
# X/X-X || 301
# log(5-5) || 297
# sqrt(C-C) || 269
# X || 264
# log(X) || 261
# log(C^3) || 250
# cos(C)-C || 225
# log(sqrt(X)) || 214
# log(C^3-C*C) || 203
# cos((C-X)^3) || 203
# log(C) || 197
# log((C^5)^3) || 187
# log(C-5) || 185
# log(3) || 183
# log(C^2-C*C) || 171
# C/(log((((((((X^C-C)*C)*C)*C)*C)*C)*C)*C)*C)^(C^5) || 169
# log(log(exp(exp(C*C-C))+C)) || 160
# cos(((C+X)^5)^5) || 152
# C*sqrt(X) || 150
# log(sqrt(X))*cos(cos(X)) || 145
# log((sqrt(X)+C)^C) || 144
# log(log(exp(exp(C*C))+C/C)) || 137
# log(C^2-X/X) || 136
# C*sqrt(C) || 135
# sqrt(((sin((X^5)^5)+X)+C)-C) || 133
# log(cos(X)) || 129
# sqrt(sqrt(X+C))-C*(C*(C*C)) || 129
# sqrt(sqrt(C))*cos(cos(X)) || 119
# log(5-C) || 115
# log(log(log(log(log(log(log(log(C)))))))-C) || 113
# cos((C^5)^5) || 112
# log(C^3-C*X) || 110
# C+cos(cos(cos(C*X)))^5 || 107
# cos(((C+exp(C))-C)^3) || 105
# cos((C-X)^5) || 104
# log(log(log(log(log(log(log(C))))))-C) || 103
# X*C || 102
# C*exp(X) || 102
# log(X^3) || 101
# log(C^2-C^4*C) || 100
# log(log(exp(exp(C*C-C))+C/C)) || 100
# C*C || 100
# cos(C)*C || 99
# C^5*X || 99
# log(5-3) || 98
# sin(C)+(((((((X^C)^C*C)*C)*X)^5)^4)^5)^4 || 98
# C^3*C || 97
# sqrt(((X^5)^5+X)-C) || 94
# log((C-C^2*C)^2-C*C) || 93
# sqrt(3) || 93
# sqrt(sqrt(X))*cos(X) || 92
# sqrt(((sin(((C+X)+X)+X)+C)-C)-C) || 89
# cos(log(log(X^(C^2*C)+C^2*C))) || 88
# (exp(exp((C-C)-C))-C*C)-3 || 85
# log(C^3-C/X) || 85
# log((C-sin(C))^3-C) || 85
# log(log(exp(exp(C-C))+C)) || 85
# cos(((C+exp(C))-X)^3) || 85
# C/((log((X-C)^2)*C)*(((X*C)*C)*X+sqrt(X))^log((X*C)*C)) || 85
# X/C-X || 84
# log((C-X*C)^3-C) || 84
# cos(C) || 84
# sqrt(sqrt(C+C))-C*(C*(C*C)) || 82
# cos(sqrt(sqrt(cos(((C^2)^3)^(X*C))))) || 82
# C^4*X || 82
# log(sqrt(sqrt(X))) || 80
# log(log(exp(exp(C-C))+C/C)) || 79
# cos(C^5) || 78
# (exp(((exp(C*X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(C) || 77
# log(log(exp(exp(exp(C*C-C))))) || 77
# C/((cos(C^2)*C)*(((X*X)^3*X)*C)) || 77
# sqrt(sqrt(X+C*C))-C*(C*(C*C)) || 76
# cos(sqrt(log(X^(C^2*C)-C^2*C))) || 76
# C*C-C || 74
# cos(sqrt(sqrt(X+C*C))) || 74
# log(log(log(log(log(log(C)))))-C) || 72
# log((C-sin(C))^5-C) || 71
# log(C^2-C/X) || 70
# sqrt(X-exp(C)) || 70
# C/((log((X*C-C)^2)*C)*(((((X^C*C)*X)*X)*X)*C)) || 70
# log(sqrt(X^5)) || 69
# cos(X)-C || 68
# sqrt(sqrt(X^3))*cos(C) || 67
# cos(log(log(C^(C^2*C)+C^2*C))) || 67
# log(log(exp(log(C*C-C))+C/C)) || 66
# X-X/C^3 || 66
# cos(sqrt(sqrt(cos(((X^2)^3)^(X*C))))) || 66
# cos(((C+exp(C))-X)^5) || 66
# ((X-C)-(C*X)/X)-C*sqrt(X/C) || 65
# X/cos((((X*C-C)^3)^3)^4) || 65
# sqrt(sqrt(X^3))-cos(C) || 65
# (C+X)^3*C || 65
# C/(log(log(((((((X^C-C)*C)*C)*C)*C)*C)*C))*C)^(C^5) || 65
# log(log(C))-(log(C)-(X-X*cos(X))) || 65
# (((((((((X*C)*C)*C)*C)*C)*C)*C-C)-exp(C))-C/C)-((C/C)/C)/exp(C) || 64
# sqrt(5-3) || 64
# sin(C)/sqrt(C) || 64
# (sqrt((X^2)^2)/C)^2+C^2/cos(X)^2 || 64
# log(log(sqrt(X)+C)) || 64
# cos(C/C)-C || 64
# cos(sqrt(sqrt(X+C))) || 64
# ((C-C)-C)-(log(C)-(X-X*cos(X))) || 64
# (exp(exp((C-X)-C))-C*C)-3 || 63
# 3*(X*X) || 63
# log(log(X+C)) || 62
# log(log(exp(log(C*C-C))+C)) || 62
# cos(log(log(C+C*C))) || 62
# log(C-log(C^4)) || 61
# C^3-C*(C*C) || 61
# cos(sqrt(log(C^(C^2*C)-X*C))) || 61
# (exp(((((C*X)*X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(exp(C))*C || 60
# cos(sqrt(log(X^(C^2*C)-X*C))) || 60
# log((C-X*C)^3-C*C) || 59
# log(C^2-log(C^4)) || 59
# sqrt(sqrt(X)/C)+cos(C)/cos(C)^2 || 59
# X/(cos(cos(cos(X*C)))^2)^4 || 59
# sqrt(exp(X^3)-C) || 58
# X-X*C || 58
# cos(cos(C/C)) || 58
# sqrt(sqrt(C^(C^2*C)+C^2*C))-C*(C*(C*C)) || 58
# log(sqrt(X^(X*C)))*cos(cos(X)) || 58
# cos(sqrt(log(cos(((C^2)^2)^(C^2*C))))) || 58
# C/(log(log((((((X^C-C)*C)*C)*C)*C)*C))*C)^(C^2) || 58
# X^2-sqrt(C+X) || 57
# log(log(exp(exp((C*C)*C))/(C/C))) || 57
# log(sqrt(sqrt(C+C^2*C))) || 57
# cos(log(sqrt(C^(C^2*C)+C^2*C))) || 57
# (((((((((C*X)*C)*C)*X)*X)*sqrt(C))*sqrt(C)-exp(C))-C)-exp(C))-exp(exp(C+C))*C || 56
# C/(log(((((((X^C-C)*C)*C)*C)*C)*C)*C)*C)^(C^2) || 56
# C-cos(cos((C*C)/X))^4 || 55
# log(sqrt(log(C))) || 55
# sqrt(sqrt(C^(X*C)+C*C))*log(C) || 55
# log(C^3-log(C)) || 54
# sin(C)+(((((((X^C)^C)^C*C)^2)^5)^4)^5)^4 || 54
# (exp((exp(exp(C))*sqrt(C)-sqrt(C))-C)-C*C)-exp(C)*C || 53
# sqrt(C-X) || 53
# sqrt(log(log(log(X/C))+C)^2) || 53
# C*sqrt(C+X) || 53
# C/((log((X*C-C)^2)*C)*(((((X^C/C)/X)/X)*X)*C)) || 53
# (exp((exp(C)*sqrt(C)-sqrt(C))-C)-C*C)-exp(C)*C || 52
# sqrt((X-C)-C) || 52
# sqrt(sqrt(X^2)/C)+cos(X)/X^2 || 52
# X^2-C^3 || 52
# sqrt(sqrt(X^(C^2*C)+C*C))*log(X) || 52
# cos(log(sqrt(X+C^2*C))) || 52
# cos(sqrt(sqrt(cos(cos((C^2)^2))))) || 52
# X/(C*X)-C || 52
# C/((cos(C^2)*C)*(((C*X)^3*X)*C)) || 52
# C/(((X^3*C)*C)*((((X*X)*C)*X)*C)) || 52
# log((sqrt(X)+C)^3) || 51
# exp((exp(exp((C*C)*C))/exp(X))^X) || 51
# C*log(C)-C || 51
# cos(sin(C)^5) || 51
# C/((cos((X*C)^2)*C)*((((((X*C)*C)*X)*X)*X^3)*sqrt(X*C))) || 51
# log((C-X/C)^3-C) || 50
# log(log(log(log(log(log(log(log(log(C))))))))-C) || 50
# C+(cos(cos(((C*C)*C)*C))^5)^4 || 50
# cos(sqrt(sqrt(X^3))) || 50
# (C-sin(C)*sin(C+X))*(X*sin(X)) || 50
# C/((log(((X*C)*X)^X)*C)*((((X^C/C)/X)*X)*C)) || 50
# ((cos(((((((X*C)*C)*C)*C)*C)*C)*C)-sin(C))-C)-(C/C)/C || 49
# X^C-X || 49
# C*log(C)+log(sqrt((((X^C-C)-C)-C)-C)) || 49
# C+(cos(cos(((X*C)*C)*C))^3)^4 || 49
# sqrt(sqrt(log(X)+C))^(C/X+((C/C)/X)^4) || 49
# ((C-C)-C*cos(C))-((C-C)-(C-X*(X*cos(X)))) || 49
# cos((C^5)^3) || 48
# C/((cos((C*X)^2)*C)*((((((X*C)*C)*X)*X)*X^3)*sqrt(X*C))) || 48
# (log(C)-C)-(log(C)-(X-X*cos(X))) || 48
# sqrt(((((((C+X)+X)+X)+X)-C)-C)-C) || 47
# C^4/(log(((((((((X^C)^C+C)-C)-C)-C)*C)*C)*C)*C)^2-X)^4 || 47
# (((((X*C)*X-X)-X)-X)-sin(X))^4 || 46
# log(C^3-log(C^4)) || 46
# exp(log(exp(exp((C*C)*C))/(C/C))) || 46
# (C-C*C)-X*C || 46
# log((C-X*C)^3-3) || 45
# sqrt(((sin(sin(X^5))+X)+C)-C) || 45
# X^2-sqrt(C) || 45
# log(log(sqrt(C)+C)) || 45
# C/sin(log(log(((((X^C-C)-C)*C)*C)*C))-X) || 45
# C/C-X^3 || 45
# cos(sqrt(sqrt(cos(((C^2)^3)^(C*C))))) || 45
# cos(sqrt(log(cos((C^2)^2-C*C)))) || 45
# C/((((X^C*C)*C-X)^3*C)*((((X/C)/C)*C)*C)) || 45
# log(log(log(log(log(X/C))))^2) || 44
# log(log(log(log(X/C))+C)^2) || 44
# C/sin(log((((((X^C)^C-C)-C)*C)*C)*C-C)-X) || 44
# C-log(X)*(C*X) || 44
# sqrt(sqrt(X+C))-C*C || 44
# cos(log(log(C-C*C))) || 44
# log((C+C)^3)-((C-C*X)-(X/X-(C+C^3)*cos(X))) || 44
# ((C*log((X+X)+X))^((X^4)^5))^(((X^3)^3)^((((X^3)^3)^2)^4)) || 43
# log(sqrt(C)) || 43
# sqrt(sqrt(C^2+C^2*C))*cos(C) || 43
# sqrt(X^2)*(X*C) || 43
# cos(X^5) || 43
# C/((log((X^C*C)*X-X)*C)*((((X/C)/C)*C)*C)) || 43
# C/((cos((C*C)^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X^2))) || 43
# ((C-C)-C)-((C-C)-(C-X*(X*cos(X)))) || 43
# (exp((((((X*X)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-exp(C)*C)-C || 42
# log((C^3)^(C/C)) || 42
# sqrt(sqrt(C^(C^2*C)+C^2*C))*cos(exp(X)) || 42
# cos(sqrt(sqrt(cos((X^2)^(C^2*C)-C*C)))) || 42
# (X-C)-C || 41
# log((C^4)^2-C^4*C) || 41
# sqrt((X^3-C)-C) || 41
# C/C+log(sqrt(((X+C)+C)+C)) || 41
# ((C-exp(X))-C*C)-cos((((((((((((X^C-C)-C)-C)-C)*C)*C)*C)*C)*C)^2)^2)^2) || 41
# ((C-exp(X))-C*C)-cos((((((((((((X^C-C)-C)-C)-C)-C)*C)*C)*C)*C)^2)^2)^2) || 41
# log((sqrt(log(log(log(X/C+C))))-exp(C))*X) || 41
# C+(cos(cos(((X*C)*C)*C))^3)^5 || 41
# C^4/(log((((((((X^C+C)-C)-C)-C)*C)*C)*C)*C)^2-X)^4 || 41
# log(((X^X)^5)^C) || 41
# C/((log((X*C)^2)*(C*C))*((X*C)*X-X^3)^4) || 41
# log(C^3)*((C+C)^4-(C*C)*C) || 41
# (((X+C)-C)^3*C+C)-log(log(((((X^C+C)+C)+C)+C)-C)) || 40
# X^C+X || 40
# log(log(log(log(log(log((C/C)/C))))+C/C)) || 40
# log(log(exp(exp(C*C))/(C/C))) || 40
# sqrt(sqrt(C^(C^2*C)+C^2*C))*cos(exp(C)) || 40
# C/((cos(X^2)*C)*((((X*X)*C)*X)*C)) || 40
# C/(log((((((((X^C-C)-C)*C)*C)*C)*C)*C)*C)*C)^(C^2) || 40
# (X*(C*exp(C)))*((C*C+C)+X)^(C*C) || 40
# ((((((((X*C)*C)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-exp(exp(C)))-exp(exp(C+X))*C || 39
# log(C^3-cos(C)) || 39
# sqrt(((((((C+X)+X)+X)+C)-C)-C)-C) || 39
# (C-C*C)+log(sqrt(((X^C-C)-C)-C)) || 39
# X+(cos(cos(cos(C*X)))^5)^4 || 39
# cos(sqrt(sqrt(C+C*C))) || 39
# C/((log((X-C)^2)*C)*((((X^C*C)*X)*X)*X)) || 39
# C/((cos((C*X)^3)*C)*(((((C*C)*X)*C)*X)*C)) || 39
# sqrt(((((((C+sin(C))+X)+X)+C)-C)-C)-C) || 38
# ((C/log((X+X)+X))^((X^4)^5))^(((X^3)^3)^(((X^3)^4)^4)) || 38
# C/sin(log((((X^C)^C*C)*C)*C-C)*C) || 38
# C/sin(log(log(log(((((((X^C)^C-C)-C)-C)*C)*C)*C)))^X) || 38
# cos(log(log(X-C*C))) || 38
# cos(sqrt(log(((X^2)^2)^(C^2*C)-C*C))) || 38
# cos((C+X)^5+X) || 38
# (3-cos((C+X)^4))*(X*X) || 38
# C/(((C^3*C)*C)*((((X*X)*C)*X)*C)) || 38
# C/((cos((X*C)^2)*C)*(((((X*C)*X)*X)*X)*exp(X^3))) || 38
# X/C-C || 37
# (X/X+X)+X || 37
# (C*X)/C+log(cos(((X-C)-C)^3)) || 37
# log((sqrt(C)+C)^C) || 37
# log((sqrt(log(log(log(X/C+C))))-exp(C+C))*X) || 37
# cos(sqrt(log(cos(((C^2)^2)^(X*C))))) || 37
# cos(((C+exp(C))+X)^3) || 37
# C/((log((X-C)^2)*C)*(((((X*C)*X)*X)*X^3)*X)) || 37
# log((log(log((X/C)/C))+C)^3)-sin((C*C)/C+(C*C)/C) || 37
# log(sqrt(C/C+C))+((C/C)/X)/((C/C)/X)^2 || 37
# ((cos(((((((X*C)*C)*C)*C)*C)*C)*C)-exp(C))-C/C)-C/C || 36
# C+(((((((X^C)^C*C)*X)*X)^2)^4)^5)^4 || 36
# log(cos(sqrt(sqrt((C-C)+C)))) || 36
# log((exp(log((C*C)*C))/(X/C))^X) || 36
# X/C-C/C || 36
# X-cos(X)/(C*C)^5 || 36
# X+(cos(cos(cos(cos(C))))^5)^4 || 36
# C/((cos((C*X)^2)*C)*((((X*X)*C)*X)*C)) || 36
# log(log(C))-((C-C)-(X-X*cos(X))) || 36
# (exp(exp((C-sqrt(C))-sqrt(C)))-C*C)-3 || 35
# sqrt((X/C)/C)+cos(X/C)*C^2 || 35
# sqrt((C^2/C)/C)+cos(C/C)*C^2 || 35
# sin(C)+(((((((X^C)^C*C)*C)*X)^5)^4)^5)^5 || 35
# log(log(log(log(log(log(X/C))))+(C*C)/C)) || 35
# C+(cos(cos(X*X))^5)^2 || 35
# log(sqrt(sqrt(C))) || 35
# sqrt(sqrt(X+C^2*C))-C*(C*(C*C)) || 35
# sqrt(sqrt(X^3+C^2*C))*cos(cos(X)) || 35
# cos(sqrt(sqrt(((X^2)^2)^(C^2*C)-C*C))) || 35
# C*sin(X) || 35
# C/((log(((X^C*C)*X)*X)*(C^2*C))/(((X/C)*C)*log(X/C+C))) || 35
# C/(log(((((X^C*C)*X)*C)*C)*C)*C)^((((X/C)*C)*C^2)^2) || 35
# (exp(exp(((((X*X)*X)*X)*X)*sqrt(C)-sqrt(C)))-X*C)-C || 34
# log((C-X*C)^2-C*C) || 34
# sqrt((X^5+X)-C) || 34
# sqrt(((C^5)^5+X)-C) || 34
# sqrt(sqrt(X^2)/C)+X/X^2 || 34
# log(cos(exp(log(log(log(log(X/C)))))+C/C)) || 34
# (log(log(C*C-C))-X/(C*C))^2*X || 34
# X-cos(X)/X^5 || 34
# cos(sqrt(sqrt((((C^2)^2)^(C^2*C))^(C^2*C)+C*C))) || 34
# log(((C^5)^5)^3) || 34
# cos((X+X)^5+X) || 34
# log(((C+X)^5)^5) || 34
# C/((cos(C^3)*C)*(((C*X)^3*X)*C)) || 34
# C/((cos((C*C)^2)*C)*((((((X*C)*C)*X)*X)*X^3)*sqrt(X*C))) || 34
# C/(log(((((((((X^C)^C-C)*C)*C)*C)*C)*C)*C)*C)*C)^(C^5) || 34
# (sin(C)-X)+C || 34
# (X*(C*exp(C)))*((C+C)^4*log(X)) || 34
# log((log((X/C)/C)+C)^3)-((((X/C)/C)/C)/log(C*C)+((C*C)*X)^2) || 34
# log((C+log(C^2))^3-C) || 33
# log(C^2-C^2*C) || 33
# log(C^2-cos(C^4)) || 33
# log((exp(log((C*C)*C))/(C/C))^X) || 33
# X/cos(((((X*C)*C)^3)^3)^4) || 33
# cos(sqrt(sqrt(cos(((C^2)^2)^3)))) || 33
# (X-C)*X || 33
# C/((log((X-C)^2)*C)*((((X/C)*C)*C)*X+sqrt(X))^log((X*C)*C)) || 33
# C/((((X*C)^2*C)*C)*((((((X*C)*C)*X)*X)*X^3)*sqrt(X*C))) || 33
# log(sqrt(sqrt(sqrt(log(log((X*C)*C))))))-4 || 33
# sqrt(sqrt(log(X)+C))^(C/X+((C/C)/X)^((C+C)^2)) || 33
# (exp(exp((C-sqrt(C))-C))-C*C)-3 || 32
# (C^2)^C-C || 32
# log((C^2)^(C/C)) || 32
# log(X-C*X) || 32
# log((C+X/C)^3-C) || 32
# log(C^3-C^4*C) || 32
# ((C-exp(X))-C*C)-cos((cos((((((((X^C-C)-C)-C)-C)*C)*C)*C)*C)^2)^2) || 32
# sin(X^2)+(C/C^2)^2 || 32
# ((C+C)-C)-sqrt(C) || 32
# C-cos(cos((X*C)/X))^4 || 32
# (X+C)-cos(X) || 32
# cos(sqrt(log((((C^2)^2)^2)^(C^2*C)-C^2*C))) || 32
# C*sqrt(C+sqrt(C)) || 32
# (C^2*(C/C))*((C*C+C)+X)^2 || 32
# (((((((((C*X)*C)*C)*X)*X)*sqrt(C))*sqrt(C)-exp(C))-C)-exp(C))-exp(exp(X+C))*C || 31
# (exp(((exp(C*X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(exp(C))*C || 31
# (exp((exp(C*X)*sqrt(C))*sqrt(C)-C)-C*C)-exp(exp(C))*C || 31
# sqrt(((C^3)^5+X)-C) || 31
# C/C+log(sqrt(((X^C-C)-C)-C)) || 31
# sin(C)+((((((((X^C)^C)^C*C)*C)*X)^5)^4)^5)^4 || 31
# log(cos(exp(log(((X+C)+C)+C))*log(C+C))) || 31
# log(log(exp(exp(C*C))/(X/C))) || 31
# sqrt(sqrt(C+C^2*C))-C*(C*X) || 31
# log(sqrt(X^(X*C)))*cos(cos(C)) || 31
# cos(sqrt(log(C-C*C))) || 31
# cos(sqrt(log(cos((X^2)^(C^2*C))))) || 31
# sqrt((X^2)^2)*C || 31
# X/C-C*X || 31
# C/((log((X^C-C)^2)*C)*((((X^C*C)*X)*X)*X)) || 31
# C/((cos((C*X)^2)*C)*(((((C*C)*X)*C)*X)*C)) || 31
# ((cos(((((((X*C)*C)*C)*C)*C)*C)*C)-exp(C))-C/C)-X/C || 30
# sin(((X^2/X)/X)*X^2)/(cos(X)/X^3) || 30
# X-cos(X/C)*X^2 || 30
# C+(cos(cos(((X*C)*C)*C))^2)^4 || 30
# C+(log(log(((X*C)*C)*C))^2)^4 || 30
# cos(sqrt(log(cos((C^2)^2-3)))) || 30
# (X/C)*X || 30
# (C^2)^3*(X*C) || 30
# sqrt(C^2)*(X*C) || 30
# C*exp(C/sin(C)) || 30
# C/((log((((((X^C-C)-C)*X)*X)*C)*C)*((X+C)^3*C))/C) || 30
# (log(C)-C)-((C-C)-(X-X*cos(C+X))) || 30
# log(C^2-cos(C)) || 29
# ((X/C)/C)^3+((X/C)*C)^2*C^2 || 29
# (C+C)^C-sqrt(C) || 29
# log(log(log(log((C*C)*C-C))+X/C)) || 29
# C/sin(log(log((((((((X^C)^C-C)-C)-C)*C)*C)*C)*C))-C) || 29
# C^4/(log((((((((X^C+C)+C)-C)-C)*C)*C)*C)*C)^3-X)^4 || 29
# X/cos(X)-C || 29
# C/((((X*C)^2*C)*C)*((((X*C)*C)*X)*log((X^C)^C))) || 29
# C/((((X*C)^2*C)*C)*((((((X*C)*C)*X)*X)*X)*sqrt(X^C*C))) || 29
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-((C+X)-C^2))) || 29
# X/X+X || 28
# (exp(((exp(C)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(exp(C))*C || 28
# (exp((exp(C)*sqrt(C)-sqrt(C))-C)-C*C)-3 || 28
# sqrt((X-C)-5) || 28
# sqrt(exp((sin((((C+X)+X)+X)+X)+C)-C)) || 28
# C/(C*C)+log(((((X^C-C)-C)-C)-C)^3) || 28
# ((C-X/C)-C*C)-cos((((((((((((X^C-C)-C)-C)-C)*C)*C)*C)*C)*C)^C)^2)^2) || 28
# ((X/C)/C)^3+((X/C)*C)^2*X^2 || 28
# sqrt((X^2)^3/C)+cos(C)/X^2 || 28
# (((X^C+C)+C)-C*X)^2-C || 28
# log((exp(log((X+C)+C))-log(C))*exp(C+C)) || 28
# X-X/C^5 || 28
# C/sin(log(log((((((X^C)^C-C)-C)*C)*C)*C))-C) || 28
# C-cos(X^3) || 28
# C*log(C)-cos(X) || 28
# log((C/C)^3) || 28
# cos(sqrt(sqrt(((X^2)^(C^2*C))^(C^2*C)+C*C))) || 28
# cos(X)*X || 28
# sqrt(((C^3)^3)^C)*X || 28
# log(((C-sqrt(C))^5)^5) || 28
# C*exp(C+sin(C)) || 28
# C/((log((X*C)^2)*(C*C))*((X*C)*X-X^3)^((X*C)/C)) || 28
# C/((log((X-C)^2)*C)*(((X*C)*C)*X+sqrt(X))^sqrt((X*C)*C)) || 28
# C/((((X^C*C)*C-X)^3*C)*(((((X/C)/C)/C)*C)*C)) || 28
# C/(((X^2*C)*C)*((((X*X)*C)*X)*C)) || 28
# C/(((C^2*C)*C)*((((X*C)*C)*X)*C)) || 28
# (((C+C)+C)-cos(C+C))*C^3 || 28
# (sqrt(log(log((X/C)/C))+3)^3-C*((X/C)/C))-2 || 28
# sqrt(sqrt(sqrt(X/C)+C))+(C/X+(((X/C)/C)/((C/C)/C))^4) || 28
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C))*sqrt(C)-sqrt(C))-C)-exp(exp(exp(X))))-exp(exp(C+X))*C || 27
# (exp(((exp(C*X)*X)*sqrt(C)-sqrt(C))-C)-X*C)-exp(C) || 27
# (C^3)^C-C || 27
# log((C^3)^3) || 27
# log(C^2-X*C) || 27
# sqrt(((sin((C+C)+5)+X)+X)-C) || 27
# sqrt(X/C)+cos((C/C)*C)*X^2 || 27
# sqrt(X^3/C)+cos(C)/cos(X)^2 || 27
# (C-C)^C-sqrt(C) || 27
# log(log(log(log((X*C)*C)))-(C*C)/exp(C))*X || 27
# log((exp(log((C*C)*C))/(X/C))^(sqrt(C+C)+log(X))) || 27
# C/sin(log(log(((((((X^C-C)-C)-C)*C)*C)*C)*C))-C) || 27
# sqrt(sqrt((C^3)^(X*C)))*cos(exp(C)) || 27
# log((X^5)^3) || 27
# C*sqrt(C^X) || 27
# C/((log(((X*C)*C)^X)*(C*C))*((X*C)*X-X)^4) || 27
# C/((log((X-C)^2)*C)*(((((X*C)*X)*X)*X^3)*C)) || 27
# C/((log(((X*C)*C)^2)*C)*(((((X^C/C)/X)/X)*X)*C)) || 27
# C/((cos((X*C)^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X^2))) || 27
# C/((log(((X*C)*X)*X)*((X/C)^3*C))/(C^2*log((X*C)*C))) || 27
# C/(log((((((X^C*C)*X)*C)*C)*C)*C)*C)^(cos(C)^3) || 27
# log(((log(log((X/C)/C))+C)+3)^3)-(X+(C/C)^2) || 27
# log((((X*C-C)-C)+C)^3)+(((X*C)*C)/exp(C)+exp(C*C))^4 || 27
# log(X)-((C-C)-(X/C)*((C/X)*cos(X))) || 27
# (log(C)-C)-((C-C)-(X-X*cos(X))) || 27
# ((C-C)-C*(C*X))-(log(log(C))-(X-X*cos(X))) || 27
# (exp((C*X)*X)*sqrt(C))*sin(X)-C^5/X || 26
# (cos(((((((X^C*C)*X)*X)*C)*C)*C)*C)*sin(C)-C)-X/C || 26
# ((((((((C*X)*C)*X)*X)*X)*sqrt(C))*sqrt(C)-exp(C))*C-exp(C))-exp(exp(C+C))*C || 26
# (C/C)/C-X || 26
# (X*C)/(C*C)+log((((X^C-C)-C)-C)^3) || 26
# (((X+C)+C)^3*C+C)-log(log(((((X^C+C)+C)+C)+C)-C)) || 26
# ((C-C)-C)-sqrt(C) || 26
# log(sqrt(sqrt((X-C)+C))^2) || 26
# log((((X+C)+C)-C)*((C+C)+C*C)) || 26
# log(cos(exp(log(log(log((X*C)*C))))+C/C)) || 26
# log((exp(log((C*C)*C))/exp(C))^X) || 26
# log((exp(exp((C*C)*C))/exp(C))^C) || 26
# exp(log(exp(exp(C*C))/(C/C))) || 26
# C-cos(cos((C*X)/X))^4 || 26
# C+cos(cos(cos(X)))^2 || 26
# C+(cos(cos((X*C)*C))^2)^2 || 26
# (C*X)/((((X^C*C)*C)^2)^3*X^2)^5 || 26
# C/sin(log(log(((((((X^C-C)-C)-C)*C)*C)*C)*C))-X) || 26
# log(sqrt(X^3))*cos(cos(X)) || 26
# log(sqrt(X^2))*cos(cos(X)) || 26
# cos(log(sqrt(C+X*C))) || 26
# cos(log(log(C))) || 26
# cos(log(sqrt(C+C*C))) || 26
# cos(log(sqrt(C^(C^2*C)+C*C))) || 26
# cos(sqrt(sqrt(cos(((X^2)^3)^(C*C))))) || 26
# log(cos(C-5)) || 26
# (sin(C/X)-X)+X || 26
# (exp((C*X)*X)*sqrt(C))*sin(X)-C^5*sqrt(C) || 25
# ((cos(((((((X*C)*C)*C)*C)*C)*C)*C)-sin(C))-C/C)-X/C || 25
# ((((((((((X*C)*C)*C)*C)*C)*C)*C)*C-C)-X)-C)-exp(exp(X+C))/C || 25
# ((X/C)*C)/C+cos(C)*(X*C)^2 || 25
# X-C^C || 25
# log(log(log(log(log((C/C)/C))))^2) || 25
# log(sqrt(sqrt(X))^C) || 25
# log(log(log(X*C-C))-exp(C)/exp(C))*X || 25
# log((exp(exp(C*C-C))+C)^3) || 25
# C+(cos(cos((X*C)*C))^3)^4 || 25
# C/C-C^3 || 25
# cos(log(sqrt(X))) || 25
# log(((X+X)^5)^C) || 25
# C/((cos((X*C)^2)*C)*(((((X^C*C)*X)*X)*X)*sqrt(X))) || 25
# C/((cos(X^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X^2))) || 25
# C/(log(((((((X^C*C)*C)*C)*C)*C)*C)*C)*C)^(C^2) || 25
# C/(log((((((((X^C-C)*C)*C)*C)*C)*C)*C)*C)*C)^(C^2) || 25
# (sqrt(X)^3)^((X*(C*X))^((X-C)-(X-C^4))) || 25
# (log(X)-C*cos(C))-((C-C)-(X-(C/X)*cos(X))) || 25
# (C/C)/X-X || 24
# (sqrt(X)/C-C^2/C^3)-C || 24
# ((cos((X*C)*X-X)-X)-sin(X))^4 || 24
# ((((((((((X*C)*C)*C)*C)*C)*C)*C)*C-X)-exp(C))-C/C)-exp(exp((X+C)+C))/C || 24
# (((((((((X*C)*C)*C)*C)*C)*C-exp(C))-exp(C))-C)-C/C)-(exp(C)/C)*exp(C) || 24
# (exp(((exp(X*X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(C) || 24
# (X-X)-C || 24
# sqrt((((((((C+sin(C))+X)+X)+X)+C)-C)-C)-C) || 24
# ((((((C-C)+C)+C)+C)^4+X/C)+C)-log(log((((((X^C-C)-C)-C)-C)-C)-X)) || 24
# (((((((X^C+C)+C)+C)+C)+X)+C)+C*C)-log(log((((((X^C-C)-C)-C)-C)-C)-X)) || 24
# (((((((C-C)-C/C)-C/C)-X/C)-exp(X))^exp(X^3))^4+C)-cos((((((X^C-C)-C)-C)-C)^2)^2) || 24
# ((C-exp(X))-C*C)-((cos(((((((X^C-C)-C)-C)-C)*C)*C)*C)^2)^2-C*C) || 24
# ((C-exp(X))-C*C)-((((((((((((X^C-C)-C)-C)-C)-C)*C)*C)*C)*C)^2)^2)^2-X*C) || 24
# (C^2/X)^3+(C*C)^2*C || 24
# ((C+sqrt((X+X)+X))^((((C^X)^4)^4)^5))^((((X^3)^3)^2)^4) || 24
# log(cos(exp(log(((X+C)+C)+C))*log(C))) || 24
# log(cos(sqrt(log(log(log(log(X/C)))))+C/C)) || 24
# C/sin(log(log(((((((X^C+C)-C)-C)*C)*C)*C)*C))-X) || 24
# sqrt(sqrt(C^3))-cos(C) || 24
# sqrt(sqrt(X+C*C))*log(C) || 24
# sqrt(sqrt(C^2+C^2*C))*cos(exp(X)) || 24
# sqrt(sqrt(C^(C^2*C)+X*C))*cos(X) || 24
# sqrt(sqrt(X^(X*C)))*cos(cos(C)) || 24
# log(sqrt(X^3))*cos(cos(C)) || 24
# sqrt(sqrt(X))*cos(exp(X)) || 24
# cos(sqrt(sqrt((((X^2)^(C^2*C))^(X*C))^(C*C)))) || 24
# cos(sqrt(sqrt(cos((X^2)^(C^2*C))))) || 24
# (X/C)*C || 24
# C/((((X*C)^2)^3*C)*(((X/C)*C)*X-X)^4) || 24
# C/(((((X^C*C)*X)*X)^3*C)*((((X/C)/C)*C)*C)) || 24
# ((((C*C)*X-X)-X)-sin((X^C)^3))-X/C || 23
# (((((C*C)*X-X)-X)-X)-sin(X))^4 || 23
# ((((((((((X*C)*C)*C)*C)*C)*C)*C)*C-X)-exp(C))-exp(C))-exp(exp((X+C)+C))/C || 23
# (((((((((X*C)*C)*C)*C)*C)*C-exp(C))-exp(C))-C)-C/C)-(exp(C-X)/C)*C || 23
# (exp(exp((((((X*X)*X)*X)*X)*sqrt(C))*sqrt(C)))-C*C)-(C-C) || 23
# (exp(exp((((((X*X)*X)*X)*sqrt(C))*sqrt(C))*sqrt(C)))-exp(C)*C)-C || 23
# log((C^4)^2-C^2*C) || 23
# sqrt(((sin((X+C)+C)+X)-X)-C) || 23
# sqrt((((((((C+sin(C))+X)+C)+C)+C)-C)-C)-((C^C+C)+C)) || 23
# (C+C)+sqrt(((X+C)+C)+C)*C || 23
# (((X+C)+C)^3*(C^2*C)+C)-log((((((X^C+C)+C)+C)+C)-C)*C) || 23
# (((X+C)+C)^3*log(C^2)+C)-log(((((((X^C+C)+C)+C)+C)+C)-C)*C) || 23
# ((((((C-C)+C)+C)+C)^4+C^3*C)+C)-(((((X^C+C)+C)+C)+C)-C)^C*C || 23
# ((((C-C/C)+C/C)+exp(X))^log(X)+C)-cos(((((((X-C)-C)-C)-C)-C)^2)^2) || 23
# sqrt(sqrt(X^2)*C)+C*cos(C)^2 || 23
# ((C/log((X+X)+X))^((X^4)^5))^((((C^3)^3)^3)^(((X^3)^4)^4)) || 23
# X/C-C^3 || 23
# X^2-sqrt(X) || 23
# (((C-C/C)-C)-C)-sqrt(C) || 23
# log(sqrt(sqrt(C+C))^2) || 23
# log((exp(log((X/C-C)+C))-exp(C+C))*X) || 23
# X+(cos(cos(cos(X*C)))^5)^4 || 23
# C^4/(log((((((((X^C+C)+C)-C)-C)*C)*C)*C)*C)^2-X)^4 || 23
# C/C-X || 23
# cos(sqrt(sqrt(C^2+C^2*C))) || 23
# sqrt(sqrt(X^(X*C)))*cos(exp(C)) || 23
# cos(log(log(C-X*C))) || 23
# cos(sqrt(log(cos((C^2)^(C^2*C))))) || 23
# cos(C/C)*X || 23
# sqrt((C^2)^2)*C || 23
# C-(C*X)*X || 23
# C/((cos(X^2)*C)*(((((X*C)*X)*X)*X)*exp((C^C)^3))) || 23
# C/((log(((X^C*C)*X)*X)*((X^C)^2*C))*(((X/C)*C)*log(X/C+C))) || 23
# log(((X*C-C)+C)^3)+(((X*C)/C)/exp(C)+exp(C*C))^4 || 23
# log((log((X/C)/C)+C)^3)-((((X/C)/C)/C)/log(C*C))/((C*C)*X)^2 || 23
# log(sin(C+C))^((X-C*X)-(X/X-((C+C^2)-(C+X)^2))) || 23
# X/C+X || 22
# ((X-C)-(C*X)/X)-C || 22
# (((C-X)-C)-exp(X*X))-C*sqrt(C) || 22
# ((((C*X)*X)*C)*sqrt(X)-sin(X))-X^5/C || 22
# ((((((X*C)*C)*C)*X)*C)*sqrt(C)-C)-sin((C*C)^3)/C || 22
# ((cos(((((X*C)*C)*C)*C)*X)-sin(C))-C)-exp(sqrt((X+C)+C))/C || 22
# (((((((((X*C)*C)*C)*C)*C)*C)*C-C)-exp(C))-C/C)-(X/C)/exp(C) || 22
# (((((((((X*C)*C)*C)*C)*C)*C-exp(C))-exp(C))-C)-C/C)-(exp(C-X)/C)*exp(C) || 22
# (exp(exp((exp(C)-sqrt(C))-C))-C*C)-3 || 22
# (exp(((exp(C*X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(C)*C || 22
# (exp((((((C*X)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-exp(C)*C)-C || 22
# log(C^3-C^2*C) || 22
# sqrt((((C^5)^5)^5+X)-C) || 22
# ((C-exp(C))-X*C)-((cos((((((X^C-C)-C)-C)-C)*C)*C-C)^2)^2-C*C) || 22
# sin(X)/sqrt(C) || 22
# sin(X)/sin(X*X^3) || 22
# sin(C^2)+(C/X^3)^2 || 22
# sqrt(sqrt(X)/C)+cos(C)/cos(X)^2 || 22
# (C*sqrt(((X+C)+C)+C))/((((X-C)-C)^3)^4)^5+(((X^3)^3)^2)^4 || 22
# X^C-sqrt(C) || 22
# log(log(log(log(log(X/C))))^(X-X*X)) || 22
# log(sqrt(X+C)^(C+X*C)) || 22
# log(cos(exp(log(log(X*C-C)))/(C/C))) || 22
# log(log(exp(log((C*C)*C-C))+C/C)) || 22
# log(log(exp(log((C*C-C)-C))+C)) || 22
# (exp(log((X*C)*C-C))-X/C)^2*X || 22
# exp(log(exp(exp((C*C)*C))/exp(C))) || 22
# X/((cos((X*C)^3)^2)^2)^4 || 22
# (C*sqrt(X))/sin(((((X^C)^C*C)*C)^C)^3*X) || 22
# C/sin(log((((((X^C)^C-C)-C)*C)*C)*C-C)-C) || 22
# C/sin(log(log(log((((((X^C-C)-C)-C)*C)*C)*C)))+X) || 22
# sqrt(sqrt(C+C^2*C))-C*(C*(C*C)) || 22
# sqrt(sqrt(C^(C^2*C)+C*C))*log(C) || 22
# cos(log(sqrt(C+C^2*C))) || 22
# C/((X*C)*((X*C^2)*X^2)) || 22
# C/(((C^3*C)*C)*((((C*X)*C)*X)*C)) || 22
# C/(((X*X)*C)*((((C*X)*C)*X)*C)) || 22
# C/((cos((X*C)^2)*C)*(((((X*C)*X)*X)*X^3)*(X*C)^3)) || 22
# log(sqrt(sqrt(sqrt(log(log((X*C)/C))))))-2 || 22
# (X-C*cos(X))-((C-C)-(X-(C/X)*cos(X))) || 22
# ((((X*X)*X)*X)*sqrt(C)-sin(X))-sin((X*C)^5) || 21
# (((((((((X*C)*C)*C)*C)*C)*C-exp(C))-exp(C))-C)-C/C)-(exp(X)/C)*exp(C) || 21
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C)-exp(C))-exp(X))-exp(C))-exp(exp(exp(C))))-exp(exp(C-X))*C || 21
# ((((((((X*C)*X)*X)*X)*sqrt(C))*sqrt(C)-sqrt(C))-sin(C))-exp(C))-exp(exp(exp(X+C))) || 21
# ((((((((X*C)*C)*X)*X)*sqrt(C))*sqrt(C)-exp(C))-C)-exp(C))-exp(exp(C+C))*C || 21
# (exp((exp(C)*sqrt(C)-sqrt(C))-C)-C*C)-exp(X)*C || 21
# (exp(((exp(C)-sqrt(C))-sqrt(C))-C)-C*C)-3 || 21
# (exp(exp((exp(C)-sqrt(C))-sqrt(C)))-C*C)-3 || 21
# (exp((exp(exp(C))*sqrt(C)-sqrt(C))-C)-C*C)-exp(C) || 21
# (exp(exp((((((X*X)*X)*X)*sqrt(C))*sqrt(C))*sqrt(C)))-X*C)-(C-C) || 21
# exp((((((X^3)^3+3)+C)+C)+X)^4+X)-(((((X^C-C)-C)-C)-C)-X)^3*C || 21
# exp(X)+X || 21
# (X^2/X)/C+cos(X*X)*C || 21
# ((X*C)*X)/(C^4*(X*C)^3)+cos(C)*C || 21
# sin(C)+(((((((X^C)^C*C)*C)^2)^5)^4)^5)^5 || 21
# (C*sqrt(((X^C+C)+C)+C))/((((C-C)-C)-C)^4)^5+(((X^3)^3)^2)^4 || 21
# ((C*log((X+X)+X))^((X^4)^5))^(((X^3)^2)^(((X^3)^4)^4)) || 21
# log(log(sqrt(sqrt(C+C)))) || 21
# log((sqrt(X)+C)^(C+X*C)) || 21
# log((sqrt((X+C)+C)-(C-C))*(C+C)^(C*C)) || 21
# log(cos(exp(log(log(log((X/C)*C))))/(C/C))) || 21
# (log(log(X*C-C))-X/(C*C))^2*X || 21
# log(log(exp(exp(exp((C*C)*C-C))))) || 21
# C-X/X^3 || 21
# C^4/(log((((((((X^C)^C-C)-C)-C)*C)*C)*C)*C)^3-X)^4 || 21
# C-log(C)*(C*X) || 21
# cos(log(sqrt(X+C*C))) || 21
# cos(sqrt(sqrt((((X^2)^2)^2)^(C^2*C)-C^2*C))) || 21
# X^3*cos(C^2) || 21
# log(((C-sqrt(C))^5)^3) || 21
# C-(C*X)*(X/C) || 21
# C*((C*X)*(X/C)) || 21
# C/((X*C)*((X*C)^(C^2)*X^2)) || 21
# C/((log((X-C)^2)*C)*(((((X/C)*C)*X)*X^3)*C)) || 21
# C/(((((X^C*C)*C)*X)^3*C)*((((X/C)/C)*C)*C)) || 21
# C/((log(((X^C*C)*X)^X)*C)*((((X/C)/C)*C)*C)) || 21
# C/(((((X*C)*C)^X)^3*C)*((((X/C)/C)*C)*C)) || 21
# C/((cos(C^3)*C)*(((X*X)^3*X)*C)) || 21
# C/((cos((X*C)^2)*C)*((((((X*C)*C)*X)*X)*X^3)*sqrt(X^C*C))) || 21
# C/((cos((X*C)^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X*C))) || 21
# C/((log(((X*C)*X)*X)*((X/C)^3*C))/(C*log((X*C)*C))) || 21
# C/(log(((((X^C*C)*X)*C)*C)*C)*C)^(((X*C)*C^2)^3) || 21
# log(sqrt((X*C+C)^3))*(((X*C)/C+X)^2*log(C*C-C)) || 21
# (sqrt(sqrt(sqrt(log(log((X*C)/C)))))-C)-2 || 21
# log((log(sqrt(X/C))+C)^3)^((C*C)/X+((C*C)/C)^2) || 21
# sqrt(sqrt(exp(log(X))))^(C/X+((C/C)/X)^((C+C)^2)) || 21
# (((C-X)-C)-exp(X*X))-C*sqrt(C*C) || 20
# ((((X*C)*X-X)-X)-sin(((X*C)*C)/X))-X/C || 20
# (((((((X*C)*C)*C)*C)*C)*C)*sqrt(C)-X)-sin(exp(((C*C)*C)*C)) || 20
# (((((((X*C)*C)*C)*C)*C)*C)*X-C)-sin(exp((X*C)*C)) || 20
# ((((((((((X*C)*C)*C)*C)*C)*C)*C)*C-X)-exp(C))-exp(C))-exp(exp((C+C)+C))/C || 20
# (X/C-C)-C || 20
# X^C-C || 20
# log((C-sin(X))^3-C) || 20
# log((C^4)^3-log(C)) || 20
# sqrt(C-exp(C)) || 20
# ((((((X^3+C)+C)+C)+C)^3+C)+C)-log(log(((((X^C-C)-C)-C)-C)-C)) || 20
# (((((((C^C+C)+C)+C)+C)+X)+C)+C*C)-log(log(((((((X^C-C)-C)-C)-C)-C)-C)-X)) || 20
# (((((((X^C+C)+C)+X)-X)^sqrt(X))^4)^sqrt(C)+C)-((((X^C-C)-C)-C)^3)^3*C || 20
# (((((C-C)-C/C)-X*C)-exp(X))-C*C)-cos(cos(((((((X^C-C)-C)-C)-C)-C)-C)^2)) || 20
# ((C-log(C))-cos(C)*C)-((cos((((((X^C-C)-C)-C)*C)*C)*C-C)^2)^2-cos(C)*C) || 20
# ((X*C)/X)/((C/C)^2*X^3)+cos(C*X)*C || 20
# ((C+C)+C)-sqrt(C) || 20
# log(cos(sqrt(log((C/C+C)+C))*log(C))) || 20
# log(cos(exp(log(log(log(C/C+C))))-log(C))) || 20
# log((exp(exp(C*C-C))+C/C)^2) || 20
# exp((exp(log(((C*C)*C)*C))/exp(C))^X) || 20
# X-X/X^5 || 20
# C+(cos(exp((X*C)*C))^2)^2 || 20
# C+(cos(cos(((C*C)*C)*C))^3)^4 || 20
# (C*sqrt(C))/(((X^C*C-C)^3)^3*X)^4 || 20
# X/(log(((((((X^C)^C-C)-C)-C)*C)*C)*C)^3*X)^4 || 20
# sin(C)/(((((((((((((X^C)^3+C)+C)-C)-C)-C)*C)*C)*C)*C)*C)*C)^C-X)^X || 20
# C-log(C/C)*(C*log(X)) || 20
# cos(C/C)*C || 20
# sqrt(sqrt(X^3))*cos(X) || 20
# sqrt(sqrt(X+C))*cos(C) || 20
# sqrt(sqrt(X))*cos(cos(X)) || 20
# sqrt(sqrt(C^2+C^2*C))*cos(cos(X)) || 20
# cos(sqrt(log(cos(((C^2)^(C^2*C))^(X*C))))) || 20
# cos(sqrt(sqrt(cos(((C^2)^2)^(X*C))))) || 20
# cos(sqrt(log(cos((C^2)^2-X*C)))) || 20
# sqrt(((C^3)^3)^2)*log(C^2) || 20
# sqrt(X^2)*exp(X) || 20
# log(((X+X)^5)^X) || 20
# C/((cos((X*C)^2)*C)*(((((X*C)*X)*X)*X^3)*sqrt(X*C))) || 20
# (sqrt(sqrt(log(log((X/C)/C))))^3-C*((X/C)/C))-2 || 20
# (sqrt(X)^3)^((C*(C*X))^((X-C)-((C+X)-X^4))) || 20
# (X-C)-(C*C-(log(C)-(X-X*C^2))) || 20
# X/X-C/C || 19
# (((((C*C)*X-X)-X)-X)-sin(X))^sin(X^3) || 19
# ((((((((X*C)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-C)-exp(C))-exp(exp(X))/C || 19
# log(C^3-X/X) || 19
# sqrt(((((((C+sin(C))+X)+X)+X)-C)-C)-C) || 19
# (X/exp(C)+C/C)+(((X+C)+C)-C) || 19
# (C-C*C)+log(sqrt(((X-C)-C)-C)) || 19
# ((((((X+C)+C)+C)+3)+C*C)+C)-log(cos((((((X^C-C)-C)-C)-C)-C)-X)) || 19
# (((((C-C)+C/C)+exp(X))+exp(X))-C*C)-cos((((((((X^C-C)-C)-C)-C)-C)-C)^2)^2) || 19
# (((C-X)-exp(X))-C*C)-cos((((((((((((X^C)^C-C)-C)-C)-C)*C)*C)*C)*C)^C)^2)^2) || 19
# sqrt(X*C)+cos(C*X)*(C*C)^2 || 19
# ((C^2/C)/C)^3+((X/C)*C)^2*X^2 || 19
# sin((C/X)/(C^3)^3)+(((X^C)^X*X)^2*C)*X || 19
# sin(C)+(((((((X^C)^C*C)*C)*2)^5)^4)^5)^5 || 19
# (C*sqrt(((X+C)+C)+C))/((((X-C)-C)^3)^4)^5+(((C^3)^3)^2)^4 || 19
# (C*sqrt(((X^C+C)+C)+C))/((((C-C)-C)-C)^4)^5+(((C^3)^3)^2)^4 || 19
# ((C/log((X+X)^4))^4)^(((X^3)^2)^(((X^3)^4)^4)) || 19
# log(((log(log(X^C/C))+C)+(C*C)*X)^2) || 19
# log(cos(exp(log(log(log(log((X/C)/C)))))-C/C)) || 19
# log(log(exp(log(log(X*C-C)))-C)) || 19
# (log(log(X*C-C))/((C-C)/exp(C*C)))^2*X || 19
# log(exp(log(X*C-C))-X/C)*X || 19
# log(log(exp(log(X*C-C))+C/C)) || 19
# log((exp(log((X*C)*C))/exp(C))^X) || 19
# exp((exp(log((X*C)*C))/exp(C))^X) || 19
# C-cos(cos(X/X))^4 || 19
# C+(cos(cos(((X*C)*C)*C))^5)^4 || 19
# (C*sqrt(C))/((((X^C*C)*C)^3)^3*X)^4 || 19
# C/sin(log(((((X^C-C)-C)*C)*C)*C-C)-X) || 19
# C/sin(log(log((((((X^C)^C-C)-C)*C)*C)*C))-X) || 19
# sin(C*exp((X+C)^3))/(((((((((((((X^C)^3+C)+C)+C)+C)+C)+C)+C)/C)/C+C)+C)+X)+C) || 19
# (C/C)/C-C^3 || 19
# X-cos(C^3) || 19
# sqrt(sqrt(C^(C^2*C)+X*C))*cos(exp(C)) || 19
# X^3*exp(X) || 19
# X^3*(C^2*C) || 19
# sqrt((X^3)^5)*X || 19
# log(sqrt((C^X)^5)) || 19
# log(sqrt((X^2)^C)) || 19
# X/X-C || 19
# C/((log((((X*C)*C)*X)^X)*C)*((((X^C/C)/X)*X)*C)) || 19
# C/((log(((X*C)*C)*X-X)*C)*((((X^C/C)/X)*X)*C)) || 19
# (((C+C)^3)^3*(X*C))*((C+C)^2*(C*C)^2) || 19
# ((C-C)-C)-((C*C)*C-(log(log(C))-(X-X*X^4))) || 19
# ((((((X/C)/X)*X-X)-X)-X)-X)^2 || 18
# ((cos((((X*C)*C)*C)*X)-X)-C)-sin((X+C)^3)/C || 18
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C)-exp(C))-exp(exp(C)))-exp(C))-exp(exp(exp(C))))-exp(exp(C-X))*C || 18
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C))*exp(C)-exp(exp(C)))-exp(C))-exp(exp(exp(X))))-exp(exp(exp(C)))*C || 18
# ((((((((X*C)*C)*X)*X)*sqrt(C))*sqrt(C)-sqrt(C))-C)-exp(exp(C)))-exp(exp(C-X))*C || 18
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C))*sqrt(C)-exp(C))-C)-exp(C))-exp(exp(X+C))*C || 18
# (exp((exp(exp(C))*sqrt(C))*sqrt(C)-exp(C))-C*C)-exp(exp(C))*C || 18
# (exp((exp(C*X)*sqrt(C))*sqrt(C)-C)-C*C)-exp(exp(X))*C || 18
# sqrt(X-X) || 18
# sqrt(((sin((C+C)+5)+X)-X)-C) || 18
# sqrt(((((((C+X)+X)+X)+X)-X)-C)-C) || 18
# (C*X)/C+log(log(((X^C-C)-C)-C)) || 18
# ((((((X^C)^3+C)+C)-C)-C)^3*(C^3*C)+X*C)-log(X) || 18
# ((((((C-C)+C)+C)+C)^3+X/C)+C)-log(log((((((X^C-C)-C)-C)-C)-C)-X)) || 18
# ((((((C-C)+C)+C)+C)^2+C^3*C)+C)-log(log(((((((X^C-C)-C)-C)-C)-C)-C)-X)) || 18
# (((((C-C)-C/C)+X/C)+exp(X))^4+C)-cos((((((X^C-C)-C)-C)-C)^2)^2) || 18
# (C^2/X)^3+(X*X)^2*C || 18
# sin(sqrt((X^2)^2)*C)+C^2/X^2 || 18
# (C*sqrt(((X+C)+C)+C))/((((X-C)-C)^3)^4)^5+((((X*C)^3)^2)^2)^4 || 18
# ((C*log(((C-C)-X)+X))^((X^4)^5))^(((X^3)^2)^((((X^3)^3)^2)^2)) || 18
# ((C*log(((C-X)+X)+X))^((X^4)^5))^((((C^3)^3)^3)^((((X^3)^3)^2)^4)) || 18
# ((C*log((X+X)+X))^((X^4)^5))^(((X^3)^3)^((((X^3)^3)^4)^4)) || 18
# ((C^C+C)-C)^2-sqrt(X) || 18
# log(sqrt(sqrt((X+C)+C))^(C+X*X)) || 18
# log((sqrt(log((X/C-C)+C))-exp(C+C))*X) || 18
# log(cos(log(log(((X+C)+C)+C))*log(C+C))) || 18
# log(cos(sqrt(log(log(log(X/C+C))))-log(C))) || 18
# log((exp(log(log(log(X/C+C))))-exp(C+C))*X) || 18
# log(log(log((C*C)*C-C))-exp(C)/exp(C))*X || 18
# (log(log(X*C-C))-X/C)^2*X || 18
# log((exp(log((C*C)*C-C))+X/C)^2) || 18
# C-cos(cos(C*X))^4 || 18
# C+(cos(cos((C*C)*C))^5)^2 || 18
# X+(cos(cos(cos(X*X)))^5)^4 || 18
# X+(cos(cos(cos(X-X)))^5)^4 || 18
# (C*X)/((((X^C*C)*C)^X)^3*X^2)^5 || 18
# (C*sqrt(X-C^2*X))/sin((((X^C*C)*C)^C)^3*X) || 18
# C-cos(X^C) || 18
# C-X*C || 18
# X^3-C || 18
# X-C*(C*C) || 18
# sqrt(sqrt(C^(C^2*C)+C^2*C))*cos(X) || 18
# cos(log(sqrt(X^(C^2*C)+C*C))) || 18
# cos(sqrt(sqrt(((X^2)^(C^2*C))^(C^2*C)-C*C))) || 18
# cos(sqrt(sqrt(cos(((C^2)^3)^3)))) || 18
# X^3*(X/C) || 18
# (X^2)^3*(C^2*C) || 18
# (X^C)^3*(X*X) || 18
# (X^C)^3*(C*C) || 18
# (((C^3)^3)^C)^3*X || 18
# (X^5)^3*C || 18
# (X^2)^3*(X*C) || 18
# cos(((C+sqrt(C))-5)^5) || 18
# C/((log((X*C-C)^2)*C)*((((X^C*C)*X)*X)*X)) || 18
# C/((((X*C)*C-X)^3*C)*((((X/C)/C)*C)*C)) || 18
# C/((cos(C^2)*C)*(((C*X)^3*sin(X))*C)) || 18
# C/((cos(C^3)*C)*((((X*X)*C)*X)*C)) || 18
# C/((cos((X*C)^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X^3))) || 18
# C/((log(((X^C*C)*X)*X)*((X^C)^3*C))*(((X/C)*C)*log(X/C+C))) || 18
# log(sqrt((X*C+C)^3))*(((X/C)/C+X)^2*log(C*C-C)) || 18
# ((((C*X)*X)*X)*sqrt(C)-sin(X))-X^5/C || 17
# ((((((X*C)*C)*C)*X)*C)*sqrt(C)-X)-sin((X*C)^3)/C || 17
# (((((((((X*C)*C)*C)*C)*C)*C)*C-C)-exp(C))-C)-(X/C)/exp(C) || 17
# ((((((((((X*C)*C)*C)*C)*C)*C)*C)*C-C)-exp(C))-C/C)-exp(exp(X+C))/C || 17
# (((((((((X^C*C)*C)*X)*X)*X)*X)*sqrt(C)-X)-C)-C/C)-((C/X)/C)*C || 17
# (((((((((X*C)*C)*C)*C)*C)*C-exp(C))-exp(C))-C)-C/C)-exp(exp(C-X))*C || 17
# (((((((((X*C)*C)*X)*X)*X)*X)*exp(C)-exp(C))-C)-exp(exp(C)))-exp(exp(C-X))*C || 17
# ((((((((X*C)*C)*X)*X)*sqrt(C)-sqrt(X))-sqrt(X))-X)-exp(exp(C)))-exp(exp(C+X))*C || 17
# (exp(((((X*X)*X)*X)*sqrt(C)-sqrt(C))-C)-C/C)-exp(exp(C))*C || 17
# (exp((exp(exp(C))*sqrt(C))*sqrt(C)-C)-C*C)-exp(exp(C))*C || 17
# (exp((exp(exp(C))*sqrt(C)-sqrt(C))-C)-C*C)-exp(exp(C))*C || 17
# (((((exp(C*X)*X)*sqrt(C)-sqrt(C))-C)-C)-C*C)-exp(C) || 17
# X*X-X || 17
# log(((C-X*C)-C)-3) || 17
# (C/exp(C)+C/C)+((((X+C)+C)+C)-C) || 17
# (C*exp(C^3))/C+log(log(((X^C-C)-C)-C)) || 17
# (((((X+C)+C)+3)+C*C)+C)-log(cos(((((((X^C-C)-C)-C)-C)-C)-C)-X)) || 17
# ((C-log(C))-C*C)-((cos(((((((X^C-C)-C)-C)-C)*C)*C-C)-C)^2)^2-cos(C)*C) || 17
# sin(X)+(C/X^3)^5 || 17
# sqrt(X*C)+cos(X*X)*cos(X) || 17
# sqrt(X)+cos((C/C)*C)*X^2 || 17
# sqrt((C^2/C)/C)+cos(X)*C^2 || 17
# sqrt((X^2)^3/C)+cos(C)/cos(C)^2 || 17
# sqrt((X^2)^3/C)+cos(X)/X^2 || 17
# sqrt(sqrt(X^2)/C)+cos(X)/C^2 || 17
# sin(C/log((X+C)+C))+cos(((((((X^C)^C)^C)^3)^5)^4)^5) || 17
# (C*log((X^C+C)+C))/((X^C-C)^3+X)^5+(((X^3)^3)^2)^4 || 17
# (C*sqrt(((X+C)+C)+C))/((((X-C)-C)^3)^4)^5+((((C*C)^3)^3)^2)^4 || 17
# (C*sqrt(((X^C+C)+C)+C))/(((X-C)-C)^4)^5+(((X^3)^3)^2)^4 || 17
# (C/((X+X)+X)^3+(((X*C)*X-X)^4)^2)^(((C^3)^2)^((X^2)^4)) || 17
# X/C-C^C || 17
# cos(((C-X/C)-C)-C) || 17
# ((log(log(X^C/C))+C)+(C*C)*X)^2/C || 17
# log(log((X+C)^C)) || 17
# log((((C+C)+C)-C)^2) || 17
# log((sqrt(log(log(X/C-C)))/exp(C+C))*C^2) || 17
# log((sqrt(log((X/C+C)+C))*exp(C+C))*C^2) || 17
# log(cos(sqrt(log(((X+C)+C)+C))*log(C+C))) || 17
# log(cos(exp(log(log(log((C*C)*C))))/(C/C))) || 17
# X-(C/C)/X || 17
# C+(cos(cos(X*C))^5)^2 || 17
# X/(cos(cos(cos((X*C)*C)))^5)^4 || 17
# X/((cos(cos(X*C))^5)^2)^4 || 17
# (X*X)/cos(((((X*C)*C)^3)^3)^4) || 17
# C/sin(log(log(((((X^C)^C-C)*C)*C)*C))*X) || 17
# C-X^C*C || 17
# sqrt(sqrt(X+C^2*C))-C*(C*(X*C)) || 17
# sqrt(sqrt((C^3)^(X*C)))*cos(X) || 17
# sqrt(sqrt((C^3)^(C*C)))*cos(X) || 17
# sqrt(sqrt(C^3+C^2*C))*cos(exp(X)) || 17
# cos(log(log(C+C^2*C))) || 17
# cos(sqrt(log((C^2)^(C^2*C)-X*C))) || 17
# cos(sqrt(sqrt(((C^2)^3)^(C^2*C)))) || 17
# cos(sqrt(log(cos(cos(C^2))))) || 17
# (C/C)^3*cos(X) || 17
# sqrt(((C^3)^3)^5)*X || 17
# sqrt((C^2)^4)*C || 17
# sqrt(X^5)*C || 17
# log(sqrt(X^2+C)) || 17
# cos(((C+exp(C))+C)^3) || 17
# cos(((C+sqrt(C))+X)^3) || 17
# (C-3)*(X*exp(X)) || 17
# log(X/cos(X)) || 17
# C/((X*C)*cos((X*X)*C^3)) || 17
# C/((log((X-C)^2)*C)*((((X^C*X)*X)*X^3)*C)) || 17
# C/((cos(C^2)*C)*(((C*X)^3*sqrt(X))*C)) || 17
# C/((cos((C*X)^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X^3))) || 17
# C/((((((X^C*C)*X)*X)*2)*(C^2*C))*(((((X/C)/C)/X)*X)*log((X^C)^C))) || 17
# (X*C)*((C*C+C)+X)^2 || 17
# log((log(log((X/C)/C))+C)^3)-sin((C*C)/C+C/C) || 17
# log(((C*C-C)+C)^3)+(((X*C)/C)/exp(C)+exp(C*C))^4 || 17
# log((log(X*C)+C)^3)-(((X/C)/C)/X+((C*C)*C)^2) || 17
# ((X/C+C)^3)^3+((C/C)/X+((C/C)/X)^4) || 17
# ((((((((X*C)*C)*C)*C)*C)*C)*C)*C^3-X)-sqrt(exp(exp(X*C-C))) || 16
# (cos(((((((X*C)*C)*X)*X)*C)*C)*C)*sin(C)-C)-(X^3/C)/C || 16
# (((((((((X^C*C)*C)*X)*X)*C)*C)*sqrt(C)-X)-C)-C/C)-(C/C)/C || 16
# ((((((((((X*C)*C)*C)*X)*X)*C)*C)*sqrt(C)-X)-C)-C/C)-((C*X)/C)*exp(C) || 16
# ((((((((C*X)*C)*C)*X)*X)*sqrt(C)-exp(C))-C)-exp(C))-exp(exp(X+C))*C || 16
# ((((((((X*C)*X)*X)*X)*sqrt(C)-sqrt(C))-sqrt(C))-sin(C))-exp(C))-exp(exp(exp(X+C))) || 16
# (((((((((X*C)*C)*X)*X)*X)*sqrt(C)-sqrt(C))-sqrt(C))-C)-exp(C))-exp(exp(C+C))*C || 16
# (exp(((exp(X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(C) || 16
# sqrt(((sin((C+X)+X)+X)-C)-C) || 16
# sqrt((((((C+X)+X)+X)-C)-C)-C) || 16
# X/C+log(((X-C)+C)-C) || 16
# C*log(C)+log(exp((((X^C-C)-C)-C)-C)) || 16
# (((((X^C+C)+C)-C)-C)^3*(C*C)+log(X)*C)-log(log(C-X*C)) || 16
# (((((((((((C-C)-C/C)-C/C)-C*C)-C/C)-X/C)-X/C)-exp(X))^exp(X^3))^exp(X))^5+C)-(((((X^C-C)-C)-C)-C)^2)^2*C || 16
# ((((((((((C-C/C)-C/C)-C/C)-C/C)-X/C)-X/C)-exp(X))^exp(X^3))^exp(X))^5+C)-(((((X^C-C)-C)-C)-C)^2)^2*C || 16
# ((C-X*C)-cos(C)*(C*C))-(cos(cos(((((((X^C-C)-C)-C)-C)*C)*C-C)-C)^2)-cos(cos(X))) || 16
# (((C-X)-exp(X))-C*C)-cos((((((((((((X^C-C)-C)-C)-C)-C)*C)*C)*C)*C)^C)^2)^2) || 16
# sin(X)+X || 16
# sin(X)+sin(X*X^3) || 16
# (C^2/X)/C+(X*X)^2*C || 16
# ((X^2)^2/C)^2+cos(X*X)/X || 16
# sqrt((C/C)/C)+((X/C)*C)^2*C^2 || 16
# sqrt(sqrt(C^2)/C)+X/cos(C)^2 || 16
# (sqrt(X^2)/C)^3/(X/cos(X)^2) || 16
# sin(((X^2)^2/C)*X^2)/(cos(X*C)/C^3) || 16
# sin(((X^2)^X/C)*X^2)+cos(C*C)/C^3 || 16
# sin((C/X)/(C^X)^3)+(((X^C)^X*X)^2*C)*X || 16
# (C*log((X^C+C)+C))/(C^2)^3+(((((X^C)^3)^3)^2)^2)^4 || 16
# (C*sqrt(((X+C)+C)+C))/((((X-C)-C)^3)^4)^5+((((X*C)^3)^3)^2)^4 || 16
# ((C/((X+X)^4)^3)^(((X^5)^4)^5))^((((X^3)^3)^2)^4) || 16
# log(log(sqrt(sqrt(X)))) || 16
# log((sqrt(log(log(log((C/C)/C))))*exp(C+C))*C^2) || 16
# log(log(log(log(log(X/C-C)))+(C/C)/C)) || 16
# exp((exp(log(((C*C)*C)*C))/exp(C))^C) || 16
# X-X/(C/C)^5 || 16
# X/(cos(cos((X*C)*C))^2)^4 || 16
# X/(cos(((X*C)*C)^3)^4*X) || 16
# X/cos((((X-C)^3)^3)^4) || 16
# (C*sqrt(C))/(((((X^C)^C*C)*C)^X)^3*X)^5 || 16
# (C*sqrt(X))/sin(((((X^C*C)*C)*C)^C)^3*X) || 16
# C/sin(log(log(((((((X^C)^C-C)-C)*C)*C)*C)*C))-X) || 16
# C/sin(log(log((((((((X^C)^C+C)-C)-C)*C)*C)*C)*C))-X) || 16
# sin(C)/((((((((((X^C+C)+C)-C)-C)*C)*C)*C)*C)*C)^3-X)^4 || 16
# cos(C)/sin((((((((((((X^C)^3+C)+C)+C)-C)-C)*C)*C)*C)*C)*C)^C-X) || 16
# (C+C)-cos(C^2) || 16
# X-C^3*C || 16
# sqrt((C+C^2*C)+C)-C*(C*(C*C)) || 16
# sqrt(sqrt(C^(C^2*C)+C*C))-C*(C*(C*C)) || 16
# cos(sqrt(sqrt(C^(X*C)+C*C))) || 16
# sqrt(sqrt(X^(C^2*C)+X*C))*cos(X) || 16
# sqrt(sqrt((C^(C^2*C))^(X*C)))*cos(X) || 16
# cos(sqrt(sqrt(C))) || 16
# cos(sqrt(sqrt(((X^2)^2)^(C^2*C)+C*C))) || 16
# cos(sqrt(log(((C^2)^2)^(C^2*C)-C))) || 16
# sqrt((X^3)^2)*X || 16
# log(sqrt((C^5)^X)) || 16
# log((X^2+C)^C) || 16
# cos(((C+exp(C))+X)^5) || 16
# C*log(C) || 16
# C*sqrt(C^4) || 16
# X/(X*C)-C || 16
# C/(C*X)+(C-X) || 16
# C/((((X*C)^2)^2*C)*(((X/C)*C)*X-X^3)^4) || 16
# C/((log(((X*C)*C)^2)*C)*(((((X^C/C)/X)*X)*X)*C)) || 16
# C/((log((((X*C)*C)*X)*X)*C)*((((X^C/C)/X)*X)*C)) || 16
# C/((cos((X*C-C)^2)*C)*((((X/C)/X)*X)*C)) || 16
# C/((log(((((X^C-C)*C)*X)*X)*X)*((X+C)^3*C))/((X/C)^3*cos((C*C)^C))) || 16
# (((C+C)^3)^3*(C*C))*((C+C)^2*(C*C)^2) || 16
# ((X/C+C)^3)^3+((C*C)/X+((C/C)/X)^4) || 16
# sqrt(sqrt(exp(X)+C))+(C*X+(((C/C)/C)/X)^4) || 16
# sqrt(sqrt(sin(sqrt(sqrt(X)))))^(3^((C+C)^((C+C)^(X/C-(X/C)^2)))) || 16
# sqrt(sqrt(sqrt(X)))^((C*(X*C))^((X+C)^((C+X)-(X-X^2)))) || 16
# log(sqrt(X))^((C*(C*X))^((X-C*X)-((C+X)-cos(C)))) || 16
# (C/C)/X+X || 15
# (((X-C)-C)-X/X)-C*X || 15
# (((X-C)-C)-(C*X)/X)-C*X || 15
# ((X-C)-(C*X)/C)-C*sqrt(X/C) || 15
# (((((C*C)*C-X)-X)-X)-sin(sin(X^3)))-C || 15
# (exp(((C*C)*X)*X)*sqrt(C)-sin(C))-X*sqrt(C) || 15
# (cos((((C*C)*C)*X)*X)*sqrt(C))*X-X/C || 15
# ((((((((X*C)*C)*C)*C)*C)*C)*C)*sqrt(C)-X)-exp(exp(exp((X+C)-C))) || 15
# (((((((((X*C)*C)*C)*C)*C)*C)*C-C)-exp(C))-C)-(C/C)/exp(C) || 15
# ((((((((((X*C)*C)*C)*X)*X)*X)*sqrt(C))*sqrt(C)-sqrt(C))-X)-exp(exp(exp(X))))-exp(exp(C-X))*C || 15
# ((((((((((X*C)*C)*C)*X)*X)*X)*sqrt(C))*sqrt(C)-sqrt(C))-X)-exp(exp(exp(C))))-exp(exp(C-X))*C || 15
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C))*sqrt(C)-sqrt(C))-exp(C))-exp(exp(exp(X))))-exp(exp(C+X))*C || 15
# (((((((((X*C)*C)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-C)-exp(C))-exp(exp(C+C))/C || 15
# (exp((((((C*X)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-C/C)-exp(exp(C))*C || 15
# sqrt(5-C*(C/C)) || 15
# sqrt((X^5-C)-C) || 15
# sqrt((X^5-X)-C) || 15
# sqrt(((X^3)^5+X)-C) || 15
# sqrt(((sin((X+C)+5)+X)-X)-C) || 15
# sqrt((((((C+X)+X)+sin(C))-C)-C)-C) || 15
# (X*log(X^2)+C)+log(log(((X^C+C)-C)-C)) || 15
# (((C-C)-C)^3*C+C)-log(log((((((X^C+C)+C)+C)+C)+C)-C)) || 15
# (((C-C)-C)^3*log(C^2)+C)-log(((((((X^C+C)+C)+C)+C)+C)-C)-C) || 15
# (((((C-C/C)+C/C)+exp(X))+exp(X))-C*C)-cos((((((((X^C-C)-C)-C)-C)-C)-C)^2)^2) || 15
# (((C-X)-X*C)-C*C)-((((((((((((X^C-C)-C)-C)-C)-C)*C)*C)*C)*C)^2)^2)^2-X*C) || 15
# (((C-X)-X/C)-C*C)-cos(((((((((((((X^C)^C-C)-C)-C)-C)*C)*C)*C)*C)*C)^C)^2)^2) || 15
# ((C^2)^2/X)/C+(C*X)^2*C || 15
# (X/X)/(C^2*X^3)+cos(X*X)*C || 15
# (X/X)/(C^2*X^2)+cos(X*X)*C || 15
# ((C^2*C)*C)^2+cos(X*X)/X^4 || 15
# (cos(X)*C)/C+cos(C*X)*X^2 || 15
# sin((C/X)/(C^3)^3)+(((X^C)^C*X)^2*C)*X || 15
# sin(C*X^3)+cos((((X^C)^C*X)*X)^4)*X || 15
# sin(C*X^3)+((((X^C)^C*X)^2)^4)^2*X || 15
# sin(C)+((((((X^C)^C*C)*C)*X)*X)^4)^2*X || 15
# sin(C)+(((((((X^C)^C*C)*X)^2)^5)^4)^5)^4 || 15
# sin(C)+(((((((X^C)^C*C)*X)*2)^5)^4)^5)^5 || 15
# ((((X^C)^C+C)+C)-(C*C)*C)^(C^3-X)-C || 15
# sqrt(((log((X/C)/C)+C)+C)^(X-X*C^2)) || 15
# log(cos(exp(log(((X+C)+C)+C))-log(C+C))) || 15
# log(cos(exp(log((X/C+C)+C))-log(C+C))) || 15
# log(log(log(log(log(log((X/C)/C))))+C/C)) || 15
# log(log(log((C*C)*C-C))-X/C)*X || 15
# log(log(log(C*C-C))-X/(C*C))*X || 15
# (exp(log((C*C)*C-C))-X/C)^2*X || 15
# X-X*X || 15
# X-(C/C)*X || 15
# X-cos(cos(X*X))^4 || 15
# C+cos(cos(cos(C*X)))^2 || 15
# X/((cos(cos(X*C))^3)^2)^4 || 15
# X/((cos((X*C)*X)^2)^2)^4 || 15
# X/(cos((X*C-C)^3)^4*X) || 15
# C/sin(log(((((((X^C+C)-C)-C)*C)*C)*C)*C)^C-X) || 15
# C/sin(log(log(log(((((((X^C)^C+C)-C)-C)*C)*C)*C)))-X) || 15
# X/(log(((((((X^C-C)-C)-C)*C)*C)*C)*C)^3-X)^4 || 15
# sin(C)/(log((((((((X^C+C)+C)-C)-C)*C)*C)*C)*C)^3-X)^4 || 15
# sin(((X-C)*C)*exp(((X^C+C)+C)+C))/(((((((((((X^C+3)+C)+C)+C)+C)+C)+C)/C)/C+C)+X)*X) || 15
# C/C-cos(X) || 15
# cos(C)-C*(X*C) || 15
# sqrt(sqrt(C^2+C^2*C))*cos(exp(C)) || 15
# log(sqrt((C^3)^(X*C)))*cos(cos(C)) || 15
# sqrt(sqrt(C))*cos(exp(X)) || 15
# log(sqrt(C^(C^2*C)+C^2*C))*cos(X) || 15
# cos(sqrt(sqrt(((C^2)^(C^2*C))^(X*C)))) || 15
# cos(sqrt(sqrt((X^2)^(C^2*C)-C*C))) || 15
# cos(sqrt(log(cos(cos(X^2))))) || 15
# cos(sqrt(log(cos((C^2)^3-C*C)))) || 15
# log(((X^5)^5)^3) || 15
# log(((X^X)^3)^C) || 15
# log((X+X)^5+log(C)) || 15
# log(((C+X)^5)^3) || 15
# X/(X*X)-C || 15
# C-(C-X) || 15
# C*(X^3*X-sin(C*C)/X) || 15
# C/((X*C)*((C*C)^(C^2)*X)) || 15
# C/((log(((X*C)*C)^2)*C)*((((((X/C)/C)/X)*X)*X)*C)) || 15
# C/((cos(((X*C)*C)^2)*C)*((((X^C/C)/X)*X)*C)) || 15
# C/((((X*C-C)-X)^3*C)*((((X/C)/C)*C)*C)) || 15
# C/((cos(X^2)*C)*((((X/X)/X)*X)*X)) || 15
# C/(log(log(((((X^C-C)*C)*C)*C)*C))*C)^(C^2) || 15
# C/(log(((((((((X^C-C)-C)*C)*C)*C)*C)*C)*C)*C)*C)^(C^2) || 15
# (X*C)*((C*C+C)^4-C*C) || 15
# log(X^3)*((C+C)^4-(C*C)*C) || 15
# log((log((C/C)/C)+C)^3)+((C/C)/X)/((C*C)*C)^2 || 15
# log((log(X/C)+C)^3)+((C/C)/X)/((C*C)/C)^2 || 15
# sqrt(sqrt(sin(sqrt(X))))^(2^(((C+C)+C)^((C+C*C)^((C+C)-X*X)))) || 15
# sqrt(sqrt(sqrt(X)))^((C*(C*X))^((X+X)^((C+X)-cos(X)))) || 15
# (sqrt(C+C)^3)^((C*(C*X))^((X-C*X)-((C+X)-cos(C+X)))) || 15
# log(sqrt(C+C))^((C*(C*X))^((X-C)-((C+X)-C^2))) || 15
# ((C+C)^5)^3-((C-(C/X)*X)-(X/X-cos(C+C^3))) || 15
# log(X^5)-((C-C*X)-(X/X-(C+X)*cos(X))) || 15
# log(log(X))-((C-C)-(X-(C/X)*cos(X))) || 15
# ((X/C)/C-X/C^3)-C || 14
# ((X*C-C)-X/X)-C/C || 14
# ((((X*C)*X-X)-X)-sin(exp(X^3)))-X/C || 14
# (cos((((C*C)*C)*X)*X)*sqrt(C)-X)-X*X || 14
# ((((((X*C)*C)*C)*X)*C)*sqrt(C)-C)-sin((X*C)^3)/C || 14
# (((((((X*C)*C)*C)*C)*C)*C)*sqrt(C)-X)-sin(exp(exp(X*C))) || 14
# ((((((((((X*C)*C)*C)*C)*C)*C)*C)*C-C)-exp(C))-C/C)-exp(exp((C+C)+C))/C || 14
# (((((((((X*C)*C)*X)*X)*C)*C)*sqrt(C)-X)-C)-C/C)-((C*X)/C)*exp(C) || 14
# (((((((((X*C)*C)*C)*C)*C)*C-exp(C))-exp(C))-C)-C/C)-((C*C)/C)*exp(C) || 14
# (exp((((((C*X)*X)*X)*X)*sqrt(C))*sqrt(C)-exp(C))-exp(C))-exp(exp(X))*C || 14
# X^2-C || 14
# log((C^3)^(X+X)) || 14
# log(C^3-(X+X)) || 14
# log(C^5-C) || 14
# log(C^3-cos(C^4)) || 14
# log((C^4)^3-C*C) || 14
# sqrt((sin(sin(X+5))+X)-C) || 14
# sqrt((((((C+X)+X)+sin(C))+X)-C)-C) || 14
# sqrt((((((((C+sin(C))+X)+X)+X)+X)-C)-C)-C) || 14
# (C/exp(C)+C/C)+((((C+C)+C)+C)-C) || 14
# ((((((X+C)+C)+C)+C)^4+X/C)+C)-log(log((((((X^C-C)-C)-C)-C)-C)-X)) || 14
# (((C+C/C)^4+X/C)+C)-log(log((((((((X^C-C)-C)-C)-C)-C)-C)-C)-X)) || 14
# (((((((C^C)^3+C)+C)+C)+C)^3+C)+C)-log(log(((((X^C-C)-C)-C)-C)-C)) || 14
# ((((C-C/C)+C/C)+exp(X))^log(X)+C)-cos((((((X^C-C)-C)-C)-C)^2)^2) || 14
# ((((C-C/C)+C/C)+exp(X))^log(X)+C)-cos(((((((X^C-C)-C)-C)-C)^2)^2)^2) || 14
# (((((C-C)-C*C)-X*C)-X*C)-C*C)-cos(cos(cos(cos((((((X^C-C)-C)-C)-C)-C)-C)))) || 14
# (((C-X)-exp(X))-C*C)-cos((((((((((((X^C-C)-C)-C)-C)*C)*C)*C)*C)*C)^C)^2)^2) || 14
# (C^2/X)^3+X^2*C || 14
# (X^2/X)/C+(C*X)^2*C || 14
# sin((X^2*C)/X)+cos(X*X)/C || 14
# sqrt(X*C)+cos(C*X)*X^2 || 14
# sqrt(sqrt(X)/C)+cos(X)/C^2 || 14
# sin(((C^C)^2/C)*X)/(cos(X*C)/X^3) || 14
# C+(((((((X^C)^C*C)*X)*X)^2)^4)^5)^5 || 14
# (C*exp((X+C)+C)+X^3)+(((((((X^C)^C)^C)^3)^2)^2)^2)^4 || 14
# (C/(((X-C)-X)+X)^3+(((X*C-X)^X)^4)^2)^((((X^3)^2)^2)^4) || 14
# X^3-X^C || 14
# log(log(log(log((X/C)/C))+C)^2) || 14
# log(cos(sqrt(sqrt(X+C)))) || 14
# log(cos(((X+C)+C)-C)) || 14
# log((exp(log(((C/C+C)+C)+C))-exp(C))*X) || 14
# log(log(exp(log(log(X*C-C)))+C/C)) || 14
# log(log(exp(log(C-C))+C/C)) || 14
# log(log(exp(log(C-C))+C)) || 14
# exp((exp(exp((C*C)*C))/exp(C))^C) || 14
# log(log(exp(log((C*C)*C))/(C/C))) || 14
# log((exp(exp(((C*C)*C)*C))/exp(C))^X) || 14
# X-(C/C)/C || 14
# X-cos(X/C)*X^5 || 14
# X-cos(cos((X*C)/X))^4 || 14
# C+(cos(cos(X*C-C))^5)^4 || 14
# X+(cos(cos(cos(cos(X))))^5)^4 || 14
# X/((cos((X*C)^3)^3)^2)^4 || 14
# X/(cos((((X*C)*C)*C)^3)^4*X) || 14
# (C*X)/(((((X^C*C)*C)*C)^C)^3*X)^5 || 14
# X/(log(log(((((((X^C-C)-C)-C)*C)*C)*C)*C))-X)^4 || 14
# C^4/(log((((((((X^C)^C-C)-C)-C)*C)*C)*C)*C)^3*X)^4 || 14
# sin(C)/sin((((((((((((X^C)^3+C)+C)-C)-C)-C)*C)*C)*C)*C)*C)^C-X) || 14
# C-(X^C-C) || 14
# sqrt(sqrt(C^(C^2*C)+C^2*C))-C*(C*(X*C)) || 14
# sqrt(sqrt(X^(C^2*C)+C^2*C))*log(X) || 14
# sqrt(sqrt((C^2)^3+C^2*C))*cos(cos(C)) || 14
# cos(sqrt(sqrt((C^2)^(C^2*C)-X*C))) || 14
# sqrt((X^2)^C)*C || 14
# log(sqrt((C^2)^X)) || 14
# ((C-C)-(C+X)^5*X)*(X*X) || 14
# X/(C*X)-C*X || 14
# log(C)/(C*X)-C || 14
# C-(C*X)*(X/X) || 14
# C/(X^3*C-(C*C)^(C^2)*X^2) || 14
# C/(log((C*C)^2)*C-(X*C)^4*X) || 14
# C/((((X*C)^2)^3*C)*((X*C)*X-X^3)^4) || 14
# C/((log((X^C-C)^2)*C)*((((X/C)*X)*X)*C)) || 14
# C/((log((X-C)^2)*C)*(((((X/C)*X)*X)*X^3)*C)) || 14
# C/((log(((X*C)*C)^2)*C)*(((((X/C)/X)*X)*X)*C)) || 14
# C/((log((X^C*C)*X-X)*C)*((((X^C/C)/X)*X)*C)) || 14
# C/((log((X^C*C)*X-X)*C)*((((X/C)/C)*X)*C)) || 14
# C/(((((X*C)*C)^X)^2*C)*((((X/C)/C)*C)*C)) || 14
# C/((cos(C^3)*C)*((((X*X)*3)*X)*C)) || 14
# C/(((C^2*C)*C)*((((C*C)*C)*X)*C)) || 14
# C/((cos(X^2)*C)*(((((X*C)*X)*X)*X)*sqrt(X^3))) || 14
# C/((log((((((X^C-C)-C)*X)*X)*X)*C)*(C^2*(X*C)^2))/cos(X)) || 14
# C/(log(log((((((X^C-C)*C)*C)*C)*C)*C))*C)^(X^2) || 14
# C/(log(((((((((X^C-C)-C)*C)*C)*C)*C)*C)*C)*C)*C)^(C^5) || 14
# (C/C-C)+X || 14
# sqrt((log(X^C)+C)^3)*C-(((X/C)/C)/X)^2*log(C*C-C) || 14
# log(((log((X/C)/C)+C)+3)^3)-(((C*C)/exp(C)+exp(C*C))+C^2) || 14
# log(((C/C)/C+C)^3)+((C/C)/X)/((C*C)/C)^2 || 14
# sqrt(sqrt(log(X)+C))^(C/X+((C/C)/X)^((C/C)^2)) || 14
# (sqrt(C+C)^3)^((C*(C*X))^((X-(X-X*X))-((C+X)-cos(C+X)))) || 14
# sin(C+C)^3-((C-(C/X)*X)-(X/X-cos(C+C^3))) || 14
# ((C-C)-C)-(log(log(C))-(X-X*cos(X))) || 14
# (X/X)/X || 13
# (X/C-sin(X))-X || 13
# (X/C-sin(C)^4)-C || 13
# (((X/C)/C)*C-X/X^2)-C || 13
# ((((X*C-X)-X)-X)-sin(((X*C)*C)^3))-C^3/C || 13
# (((((X*C)*X-X)-X)-X)-sin(X))^sin(X) || 13
# ((((X*X)*X)*C)*sqrt(C)-sin(X))-sin((X*C)^5) || 13
# ((((X*X)*X)*X)*sqrt(X)-sin(sin(C)))-X/C || 13
# (((((C*C)*X)*X)*C)*sqrt(C))*X-X/X || 13
# (cos(((((X*C)*C)*C)*X)*X)*sqrt(C)-X)-sin(C^3)/C || 13
# (cos((((((X*C)*C)*C)*C)*C)*X)*sin(C)-C)-(sqrt(X)/C)/C || 13
# (((((((((X*C)*C)*C)*C)*C)*C)*exp(C)-X)-C)-C)-((C*C)/C)*exp(C) || 13
# (((((((((X*C)*C)*X)*X)*X)*sqrt(C)-exp(X))-exp(exp(C)))-exp(C))-exp(exp(exp(X))))-exp(exp(C-X))*C || 13
# (((((((((C*C)*C)*C)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-exp(C))-exp(exp(C+C))*C || 13
# (((((((((C*C)*C)*C)*X)*X)*X)*sqrt(C)-sqrt(C))-C)-exp(C))-exp(exp(C+X))*C || 13
# (((((((((X*C)*C)*X)*X)*X)*sqrt(C)-sqrt(C))-sin(C))-C)-exp(C))-exp(exp(C+C))*C || 13
# (((((((((X*C)*C)*C)*X)*X)*sqrt(C))*sqrt(C)-exp(C))-C)-exp(C))-exp(exp(C+C))*C || 13
# (exp((((X*X)*X)*sqrt(C)-sqrt(C))-C)-C*C)-exp(exp(C))*C || 13
# (exp(exp((((((X*X)*X)*X)*X)*sqrt(C))*sqrt(C)))-X*C)-(C-C) || 13
# log(C-C*C) || 13
# sqrt(((sin((C+C)^5)+X)+C)-C) || 13
# C/C+log(exp(((X+C)-C)+C)) || 13
# (C*exp(X))/C+log(sqrt(((X^C-C)-C)-C)) || 13
# C*log(C)+log(sqrt((((X-C)-C)-C)-C)) || 13
# (C*X)/C+log(log(((X-C)-C)-C)) || 13
# (log(((X^C+C)+C)+X)*(C^2*C))/(X*C)+log((((X+C)+C)-X*C)-C) || 13
# (((C-C)-C)^3*log(C^2)+C)-log(((((((X^C+C)+C)+C)+C)+C)-C)*C) || 13
# exp(C^4+X/C)-log(log((((((((X^C-C)-C)-C)-C)-C)-C)-C)-X)) || 13
# ((((((X+C)+C)+C)+3)+C*C)+C)-log(cos((((((X^C-C)-C)-C)-C)-C)-C)) || 13
# ((((((X^3+3)+C)+C)+C)^3+C)+C)-log(log(((((X^C-C)-C)-C)-C)-C)) || 13
# (((((C-C)-C/C)+C/C)+exp(X))^4+C)-cos(((((((X-C)-C)-C)-C)-C)^2)^2) || 13
# ((C-X*C)-cos(C)*(C*C))-(cos(cos(cos(((((((X^C-C)-C)-C)-C)*C)*C-C)-C)))-cos(cos(X))) || 13
# (((C-X)-X*C)-cos(C)*C)-(((((((((X^C-C)-C)-C)-C)*C)*C-C)-C)^2)^2-cos(C)*C) || 13
# ((C-log(C))-cos(C)*C)-((cos(((((((X^C-C)-C)-C)-C)*C)*C)*C-C)^2)^2-cos(C)*C) || 13
# (C-C*C)-cos((((((((((((X^C-C)-C)-C)-C)*C)*C)*C)*C)*C)^2)^2)^2) || 13
# sin(X)/exp(C) || 13
# sin(C^2)+(C/X^3)^5 || 13
# (X^2/X)/(C*X^3)+C^2*C || 13
# ((X/C)/X)/(C^4*(X*C)^3)+C*C || 13
# (X/X)/X^4+((X*C)*X)^2/C || 13
# (cos(X)*C)^3+cos(X*C)/cos(X)^2 || 13
# (cos(X)*C)^3+cos(X)*(X*C)^2 || 13
# sqrt(cos(X)*C)+cos(C*X)*(C*C)^2 || 13
# sqrt(cos(X)*C)+cos(C*X)*X^2 || 13
# sqrt(X/C)+((X/C)*C)^2*X^2 || 13
# sqrt((X^2/C)/C)+cos(X)*C^2 || 13
# sqrt((X^2/C)/C)+cos(X)*X^2 || 13
# sqrt(sqrt(X^2)/C)+X*cos(X)^2 || 13
# sqrt(sqrt((C^2)^2)/C)+cos(X)/X^2 || 13
# sin(((C^C/X)/X)*X^2)/(cos(C)/X^3) || 13
# sin((C/X)*(C^X)^3)+(((X^C)^X*X)^2*C)*X || 13
# sin(C)+((((((X^C)^C*C)*X)*X)^2)^4)^2*X || 13
# C+(((((((X^C)^C*C)*X)*2)^2)^4)^5)^4 || 13
# X^X-C^3 || 13
# ((C^C+C)-C)^3-C^3 || 13
# (log(((X^C)^C-C)+C)+(C*C)*C)^((X*C)^3+(X*C)*C)-X || 13
# exp(log(log(log((X/C)/C))+C)^2) || 13
# log(cos(sqrt(sqrt((X+C)+C)))) || 13
# log(cos(sqrt(sqrt(C+C)))) || 13
# log(sqrt(X+C)^C) || 13
# log((((X+C)+C)-C)^((C+C)+C)) || 13
# log((sqrt((X+C)+C)-C*C)*((C+C)+C*C)) || 13
# log((sqrt(log((C+C)+C))-C/C)-cos(C+C)) || 13
# log(cos(exp(log(log(C/C+C)+C))-exp(C+C))) || 13
# log(cos(sqrt(log(((C/C+C)+C)+C))*log(C+C))) || 13
# log(cos(sqrt(log(log(log(C/C+C))))-log(C))) || 13
# log(cos(log(log(log(log(log((X/C)/C)))))-C/C)) || 13
# log(log(exp(log((C*C-C)-C))+C/C)) || 13
# log(log(log(C-C))-X/exp(C))*(X+C/C) || 13
# log(exp(log(C*C-C))-X/(C*C))*X || 13
# exp((exp(exp((X*C)*C))/exp(X))^X) || 13
# X-X*C^3 || 13
# X-cos(cos((C*C)*X))^4 || 13
# C+cos(cos(cos(X*X)))^2 || 13
# C+(cos(cos(((X*C)*C)*C))^3)^2 || 13
# C+(cos(cos((X*C)*C))^5)^4 || 13
# X/cos(((((X*C)*C)^3)^3)^2) || 13
# (X*X)/cos((((X*C-C)^3)^3)^4) || 13
# X/cos((((X*C)^3)^3)^4) || 13
# (X*X)/(((((X^C*C)*C)^2)^2)^4)^5 || 13
# (C*X)/((((((X^C*C)*C)*C)^3)^3)^X)^4 || 13
# (C*sqrt(X))/((((X^C*C)*C)^C)^3*X)^4 || 13
# C/sin(log(((((X^C)^C-C)*C)*C)*C-C)*C) || 13
# C/sin(log(log((((((((X^C)^C-C)-C)-C)*C)*C)*C)*C))-X) || 13
# ...
# sqrt(sqrt(sqrt(sqrt(X))))^(C+(C+C)^((C+X)^(X-X*X))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(C+(C+C)^((C+X)^((C+C)-X*X))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(C+(C+C)^((C+X)^(X-X*X))) || 1
# sqrt(sqrt(sqrt(sqrt(X))))^(C+(C+C)^((C+C)^((X+C)-X*X))) || 1
# sqrt(sqrt(sin(X)))^(2^((X+C)^((C+C)^((C+C)-X*C^2)))) || 1
# sqrt(sqrt(sqrt(sqrt(X))))^(2^((C+C)^((C+C*C)^((C+X)-X*C^2)))) || 1
# sqrt(sqrt(sqrt(X)))^(2^((X+C)^((C+C*C)^((C+C)-X*X)))) || 1
# sqrt(sqrt(sqrt(X)))^(C^((C+C)^((C+C*C)^((C+C)-X*C^2)))) || 1
# sqrt(sqrt(sqrt(sqrt(X))))^(3^((X+C)^((C+C*C)^((C+C)-X*C^2)))) || 1
# sqrt(sqrt(sqrt(X)))^(3^((X+C)^((C+C*C)^((C+C)-X*C^2)))) || 1
# sqrt(sqrt(sin(X)))^(3^(((C+C)+C)^((C+C/C)^((C+C)-X*X^2)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(3^((((C+C)+C)+C)^((C+C/C)^((C+C)-X*X)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(3^(((C+C)+C)^((C+C*C)^((C+X)-X*C^2)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(3^(((C+C)+C*X)^((C+C*C)^((C+X)-X*C^2)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(3^(((X+C)+C*X)^((C+C*C)^((C+X)-X*X)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(2^(((X+C)+(C-X))^((C+C*C)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(X)))^((C*((C+X)-C))^(((X+C)+(C-X))^((C+C*C)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(2^(((C+C)-(C-X))^((C+C*C)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(2^(((X+C)-(C-X))^((C+C*C)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(X)))^(2^(((X+C)-(C-X))^((C+C*X)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(X)))^(2^(((C+C)-(C-X))^((C+C*C)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(sqrt(X))))^(2^(((C+C)+(C-X))^((C+C*X)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(X)))^((C*(C-C))^(((C+C)-(C-X))^((C+C*X)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(X)))^((C*(C-C))^(((C+C)+(C-X))^((C+C*X)^((C+X)-X*X^2)))) || 1
# sqrt(sqrt(sin(X)))^((C*(C-C))^((X+(C-X))^((C+C*X)-((C+X)-cos(X))))) || 1
# sqrt(sqrt(sin(sqrt(X))))^((C*(C-C))^((X+(C-X))^((C+C*X)-((C+X)-cos(X))))) || 1
# sqrt(sqrt(sin(sqrt(X))))^((C*(C-C))^((X+(C-X))^((C+X*X)-((C+X)-X^(X^2))))) || 1
# sqrt(sqrt(sin(sqrt(X))))^((C*(X-C))^((X+C*X)^((C+X*X)-(X-X^2)))) || 1
# sqrt(sqrt(sqrt(X)))^((C*(C*X))^((X+X)^((C+C^2)-cos(X)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X+C)^((C+X)-cos(X)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X+X)-((C+X)-X^(X^2)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X+C)^((C+X)-(C+X)^(X^2)))) || 1
# sqrt(sqrt(sqrt(X)))^((C*(C*X))^((X+C)^((C+X)-X^(X^2)))) || 1
# sqrt(sqrt(sqrt(X)))^((C*(C*X))^((X-C)^((C+X)^((C+X)-X^2)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X-C)^((C+C)-((C+X)-X^2)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X-C)^((C+X)^((C+X)-X^2)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X-C)^((C+C)-X^(X^2)))) || 1
# (sqrt(sqrt(X))^3)^((C*(C*X))^((X-C)^((C+X)-X^(X^2)))) || 1
# (sqrt(sqrt(C))^3)^((C*(C*X))^((X-C)^((C+X)-X^(X^2)))) || 1
# (sqrt(sqrt(C))^3)^((C*(C*X))^((X-C)^((C+X)-(C+X)^(X^2)))) || 1
# log(sqrt(X))^((C*(C*X))^((X-C)-((C+X)-X^4))) || 1
# (sqrt(X)^3)^((C*(C*X))^(X-((C+X)-X^4))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C)-((C+X)-(C+X)^4))) || 1
# log(sqrt(X))^((C*(C*X))^((X-C)-((C+X)-(C+X)^4))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C)-((C+C)-(C+X)^4))) || 1
# (sqrt(X)^3)^((X*(C*X))^((X-C)-((C+X)-C^4))) || 1
# (sqrt(X)^3)^((X*(C*X))^((X-C)^((C+C)-C^4))) || 1
# (sqrt(X)^3)^((X*(C*X))^((X-C)-((C+C)-C^4))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C)^(X-C^4))) || 1
# log(sqrt(X))^((X*(C*X))^((X-C)-(X-(C+X)^4))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C)-(X-(C+X)^4))) || 1
# log(sqrt(X))^((X*(C*X))^((X-C)-(X-C^4))) || 1
# (sqrt(X)^3)^((X*(C*X))^((X-C)-(X-X^4))) || 1
# (sqrt(X)^3)^((X*(C*X))^((X-C)-((C+X)-C^2))) || 1
# (sqrt(X)^3)^((X*(C*X))^((X-C*X)-((C+X)-C^2))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C*C)-((C+X)-cos(C)))) || 1
# (sqrt(X)^3)^((C*(C*X))^(X^(C-C*C)-((C+X)-cos(X)))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-(C-C*C))-((C+X)-cos(X)))) || 1
# (sqrt(C+C)^3)^((C*(X*X))^(X^(X-C*X)-((C+X)-cos(X)))) || 1
# (sqrt(C+C)^3)^((C*(X*X))^((X-(X-C*X))-((C+X)-cos(X)))) || 1
# (sqrt(sin(C))^3)^((C*(X*X))^((X-(X-C*X))-((C+X)-cos(X)))) || 1
# (sqrt(sin(X))^3)^((C*(X*X))^((X-(X-C*X))-((C+X)-cos(X)))) || 1
# (sqrt(C+C)^3)^(((C-X)*(C*X))^((X^2-C*(C-X))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(sin(X))^3)^((X*(C*X))^((X^2-(C-(C-X)))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^((X*(C*X))^((X^2-(C-X))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(sin(X))^3)^((C*(C*X))^((X^(C-C)-(C-(C-X)))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^(((C-X)*(C*X))^((X^(X-C)-(C-(C-X)))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^(((C-X)*(C*X))^((X^(C-C)-(C-(C-X)))-((C+X)-((C+X)-(C-X*X))))) || 1
# (sqrt(X+C)^3)^(((C-X)*(C*X))^((X^(C-C)-(C-(C-X)))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^((C*(C*X))^((X^(C-C)-(C-(C-X)))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^((C*(C*X))^((X^2-(X-(C-X)))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^((C*(C*X))^((X^2-X*(C-X))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X^2-X*(C-X))-((C+X)-((C+X)-(X-X*X))))) || 1
# (sqrt(X+C)^3)^((C*(C*X))^((X^2-X*(C-X))-((C+X)-cos(C+X)))) || 1
# (sqrt(X+C)^3)^((C*(C*X))^((X-(X-(C-X)))-((C+X)-cos(C+X)))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X-X*(X-X))-((C+X)-cos(C+X)))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X-X*(C*X))-((C+X)-cos(C+X)))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X-X*X)-((C+X)-cos(C+X)))) || 1
# (sqrt(C+C)^3)^((X*(C*X))^((X^2-X*(C-X))-((C+X)-cos(C+X)))) || 1
# (sqrt(C+C)^3)^(((C-X)*(C*X))^((X^2-X*(C-C))-((C+X)-cos(C+X)))) || 1
# (sqrt(C+C)^3)^(((C-X)*(C*X))^((X^2-C*(C-C))-((C+X)-cos(C+X)))) || 1
# log(sqrt(C+C))^((X*(C*X))^((X-C*X)-((C+X)-cos(C+X)))) || 1
# log(sqrt(C+C))^(((C-C)*(C*X))^((X-C*cos(C))-((C+X)-cos(C+X)))) || 1
# log(sqrt(X))^((C*(C*X))^((X-C)-(C+X)*cos(C))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C)-(C+X)*cos(C))) || 1
# (sqrt(X)^3)^((C*(C*X))^(X-(C+X)*C^2)) || 1
# log(sqrt(X))^((C*(C*X))^((X-C*X)-X*C^4)) || 1
# log(sqrt(X))^((C*(C*X))^((X-C)-X*C^4)) || 1
# log(sqrt(X))^((C*(C*X))^((X-C*X)-X*cos(C))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C*X)-(C+X)*C^2)) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-(X-C^2))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-(X-(C+X)^4))) || 1
# log(sqrt(X))^((C*(C*X))^((X-C*X)-(X-C^4))) || 1
# log(sqrt(X))^((X*(C*X))^((X-C*X)-(X-(C+X)^4))) || 1
# log(sqrt(C+C))^((X*(C*X))^((X-C*X)-((C-C)-X^4))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-((C+X)-(C+sqrt(C))^2))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-((C-X)-(C+sqrt(C))^2))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-(C-(C+X)^4))) || 1
# log(sqrt(C+C))-(C*(C*X))^((X-C*C)-(C/X-C^4)) || 1
# log(sqrt(C+C))-(C*(C*X))^((X-C*X)-(C/X-C^4)) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-(C/X-C^2))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C)-(C/X-C^2))) || 1
# sqrt(C+C)^3-(C*(C*X))^((X-X)-((C+X)-C^2)) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C*X)-((C+C^2)-(C+X)^(X-C*X)))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X-C*X)-((C+C^2)-(C+X)^2))) || 1
# (sqrt(X)^3)^((C*(C*X))^((X+X)-((C+C^2)-(C+X)^(X-X*X)))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X+X)-((C+C^2)-(C+X)^2))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X-C*X)-((C+C^2)-(C+X)^(X-X*X)))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-((C+X)-(C+X)^(X-X*X)))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-((C+C^2)-(C+X)^(X-C*X)))) || 1
# log(sqrt(C+C))^((C*(C*X))^((X-C*X)-((C+X)-(C+X)^(C-C*C)))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X-C*X)-((C+X)-(C+X)^(X-X)))) || 1
# (sqrt(C+C)^3)^((C*(C*X))^((X-C*X)-((C+X)-(C+X)^2))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X-C*X)-((C+X)-(C+X)^(X-C*C)))) || 1
# (sin(C+C)^3)^((X*(C*X))^((X-C)-((C+X)-(C+X)^2))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X-C)-((C+X)-C^2))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X-C)-((C+X)-C^4))) || 1
# sin(C+C)^3-(C-C*X)^((X-X)-((C+X)-C^2)) || 1
# (sin(C+C)^3)^((C-C*X)^((X+X)-((C+C^3)-C^2))) || 1
# sin(sin(C))^3-(C-C*X)^((X+X)-((C+C^2)-(C+X)^2)) || 1
# ((C+C)^3)^3-(C-C*X)^((X+X)-((C+C^2)-(C+X)^2)) || 1
# sin(C+C)^3-(C-C*X)^(X/X-((C+C^2)-C^2)) || 1
# (sin(C+C)^3)^((C*(C*X))^((X+X)-((C+C^2)-(C+X)^2))) || 1
# (sqrt(C+C)^3)^((C-C*X)^((X+X)-((C+C^2)-(C+X)^(X-X*X)))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X+X)-((C+C^2)-X^(X-X*X)))) || 1
# log(sin(C+C))^((C*(C*X))^((X+X)-((C+X)-(C+X)^2))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X+X)-((C+C^2)-X^2))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X+X)-((C+X)-(C+X)^2))) || 1
# (sin(C+C)^3)^((C*(C*X))^((X+C*X)-((C+X)-(C+X)^2))) || 1
# (sin(C+C)^3)^((X*(C*X))^((X-C)-(C/X-(C+X)^4))) || 1
# log(sin(C+C))^(X*(C*C^2)-((X-C)-(C/X-(C+X)^4))) || 1
# log((C+C)^3)^((X-C*X)-(X/C-(C/X-(C+X)^4))) || 1
# log((C+C)^3)^(X*(C*X)-(X/C-(C/X-(C+X)^4))) || 1
# log((C+C)^3)^((X-C*X)-((X-C)-(C/X-(C+X)^4))) || 1
# log((C+C)^5)^((X-C*X)-(X*C-(C/X-(C+X)^4))) || 1
# log((C+C)^5)^((X-C*X)-(X*C-(C/C^2-(C+X)^4))) || 1
# log(X^5)^(X*(C*X)-((X-C)-(C/X-(C+X)^4))) || 1
# log(X^5)^((X-C*X)-((X-C)-(C/X-(C+X)^4))) || 1
# log((C+C)^3)^((X-C*X)-(X*C-((C+X)-(C+X)^4))) || 1
# log(sin(C+C))^((X-C*X)-((X-C)-((C+X)-(C+X)^4))) || 1
# log((C+C)^3)^((X-C*X)-(X/C-((C+C^2)-(C+X)^2))) || 1
# log(sin(C+C))-((C-C*X)-(X/X-((C+C^2)-(C+X)^(X-X*X)))) || 1
# log(sin(C)^5)-((C-C*X)-(X/X-((C+C^3)-cos(C+X)))) || 1
# log(sin(C)^5)-((C-C*X)-(X/X-((C+C^3)-(C+X)^(X-X*X)))) || 1
# log((C+C)^5)-((C-C*X)-(X/X-((C+C^3)-cos(C+X)))) || 1
# log((C+C)^5)-((C-C*X)-(X/X-((C+C^2)-cos(C+C^3)))) || 1
# log((C+C)^5)-((C-C*X)-(X/X-((C+C^3)-cos(C+C^2)))) || 1
# log((C+C)^5)-((C-C*X)-(C/X-((C+C^3)-cos(X)))) || 1
# log((C+C)^5)-((C-C*X)-(X/X-(C+C^3)*cos(X))) || 1
# log((C+C)^3)-((C-C*X)-(C/X-(C+C^3)*cos(X))) || 1
# ((C+C)^5)^((C*X)*(X-X))-((C-(C/X)*X)-(X/C^3-cos(C+C^3))) || 1
# sin(C+C)^3-((C-(C/X)*X)-(X/X-((C+C^3)-cos(C-C^2)))) || 1
# sin(C+C)^3-((C-(C/X)*X)-(X/C^3-((C+C^3)-cos(C-C^2)))) || 1
# sin(C+C)^((C*X)*(C-X))-((C-(C/X)*X)-(X/C^3-((C+C^3)-cos(C-C^2)))) || 1
# sin(C+C)^((C*X)*(C-X))-((C-(C/X)*X)-(X/C^3-cos(C+C^3))) || 1
# sin(C+C)^((C*X)*(X-X))-((C-(C/X)*X)-(X/C^3-cos(C+C^3))) || 1
# sin(C+C)^(C*(C-X))-((C-(C/X)*X)-(X/X-cos(C+C^3))) || 1
# sin(C+C)^((C*X)*(X-X))-((C-(C/X)*X)-(X/X-cos(C+C^3))) || 1
# log((C+C)^5)-((C-C*X)-(C/X-cos(C+C^3))) || 1
# log((C+C)^5)-((C-(C/X)*X)-(C/X-cos(C+C^3))) || 1
# log((C+C)^5)-((C-(C/X)*C)-(X/X-cos(C+C^3))) || 1
# log((C+C)^5)-((C-C*C)-(X/X-cos(C+C^3))) || 1
# log(X^5)-((C-C*X)-(X/X-(C/C^3)*cos(X))) || 1
# log(X^2)-((C-C*X)-(X/X-(C+X)*cos(X))) || 1
# log(X^5)-((C-C)-(X/X-cos(C+X))) || 1
# log(X^5)-((X-C*X)-(X/X-cos(C+C^3))) || 1
# log(X^5)-((X-C*X)-(X/X-cos(X))) || 1
# log(X^2)-((C-C*X)-(X/C-cos(X))) || 1
# log(X^5)-((C-C*X)-(X/C)*cos(C+X)) || 1
# log(X^5)-((X-C*X)-(X/C)*cos(C+X)) || 1
# log(X^5)-((X-C*X)-(X/C)*((C+X)*cos(X))) || 1
# cos(X^5)-((C-C*X)-(X/C)*(X*cos(X))) || 1
# cos(X^5)-((C-C*X)-(X/C)*cos(X)) || 1
# (X^5)^(C*(X-X))-((X-C*X)-(X/X)*cos(X)) || 1
# log(X^5)-(X*C-(X/X)*cos(X)) || 1
# log(C^5)-(C*C-(X/X)*cos(X)) || 1
# log(C^5)-(C*C-(X/C)*cos(X)) || 1
# cos(C^5)-(C*C-(X/C)*cos(X)) || 1
# cos(X^5)-(X*C-(X/X)*cos(X)) || 1
# cos(C^5)-((X-C)-(X/X)*cos(X)) || 1
# cos(C^5)-((C-C)-(X/X)*cos(X)) || 1
# cos(X^5)-((C-C)-(X/X)*cos(X)) || 1
# cos(C^5)-((C-C*X)-(X/X)*cos(X)) || 1
# cos(C^2)-((C-C*X)-(X/C)*cos(X)) || 1
# (C^2-C*(X-C))-((C-C*X)-(X/C-cos(X))) || 1
# (C^5-C*(X-C))-((C-C*X)-(X/C-cos(X))) || 1
# (C^5-C*(X-C))-((C-C*X)-(X/C)*cos(X)) || 1
# (C^2-C*(X-C))-((C-C*X)-(X/C-X*cos(X))) || 1
# (C^5-C*(X-C))-((C-C)-(X/C-X*cos(C))) || 1
# (C^2-C*(X-C))-((C-C)-(X/C-X*cos(C))) || 1
# (C^2-C*(X-C))-((C-C)-(X*C-X*cos(C))) || 1
# (C^2-C*(X-C))-((C-C*X)-(X*C-X*cos(X))) || 1
# log(C^2)-((C-C*X)-(X*C-X*cos(X))) || 1
# log(C^2)-((C-C*X)-(X-X*cos(X))) || 1
# (C^2-C*cos(X))-((C-C*X)-(X-(C+X)*cos(X))) || 1
# (X-C*cos(X))-((C-C*X)-(C*C-X*cos(X))) || 1
# (X-C*cos(X))-((C-C*X)-(X*C-(C+X)*cos(X))) || 1
# (C^3-C*cos(X))-((C-C*X)-(X/C-(C+X)*cos(X))) || 1
# (C^2-C*cos(X))-((C-C*X)-(C*C-(C/X)*cos(X))) || 1
# (C^2-C*cos(X))-((C-C*X)-(C*C-(C+X)*cos(X))) || 1
# (C^2-C*cos(X))-((C-C*X)-(C/C-(C+X)*cos(X))) || 1
# (C^2-C*(X-C))-((C-C*X)-(X*C-(C/X)*cos(X))) || 1
# (C^2-C*cos(X))-((C-C*cos(C))-(X*C-(C/X)*cos(X))) || 1
# (C^2-C*(X-X))-((C-C*X)-(X*C-(C/X)*cos(X))) || 1
# (X-C*cos(X))-((C-C*cos(C))-(X*C-(C/X)*cos(X))) || 1
# log(X)-((C-C*cos(C))-(X*C-(C/X)*cos(X))) || 1
# log(C^3)-((C-C*cos(C))-(X*C-(C/X)*cos(X))) || 1
# log(C^3)-((C-C)-(X-(C/X)*cos(X))) || 1
# log(C^3)-((C-C)-(X*C-(C/X)*cos(X))) || 1
# (X^2-C*(X-C))-((C-C*X)-(X/C)*((C/X)*cos(X))) || 1
# (X^2-C*(X-X))-((C-C*X)-(X/C)*((C/X)*cos(X))) || 1
# log(X^2)-((C-C*X)-(X/C)*((C/X)*cos(X))) || 1
# log(X^5)-((C-C)-(X/C)*((C/X)*cos(X))) || 1
# log(C^2)-((C-C)-(X*C)*((C/X)*cos(X))) || 1
# log(X^2)-((C-C)-(X*C)*((C/X)*cos(X))) || 1
# (X^2-C*cos(X))-((C-C)-(X*C)*((C/X)*cos(X))) || 1
# log(C^3)-((C-C)-(X*C)*((C/X)*cos(X))) || 1
# (C^3-C*cos(X))-((C-C)-(X/C)*((C/X)*cos(X))) || 1
# (X-C*cos(X))-((C-C)-X*((C/X)*cos(X))) || 1
# (X-C*cos(X))-((C-C)-(X-X*cos(X))) || 1
# log(X)-((X-C)-(X/C)*((C/X)*cos(X))) || 1
# log(X)-((C-C)-(X-(C/X)*cos(X))) || 1
# log(X)-((C-C)-(X/C-(C/X)*cos(X))) || 1
# log(log(X))-((C-C)-(X-(C/X)*cos(C+C^2))) || 1
# (log(X)-(C-C*X))-((C-C)-(X-(C/X)*cos(C+C^2))) || 1
# (log(X)-C*(C*X))-((C-C)-(X-X*cos(C+C^2))) || 1
# (log(X)-C*cos(C))-((C-C)-(X-(C/X)*cos(C+X))) || 1
# ((C-C)-C*(C*X))-((C-C)-(X-X*cos(C+X))) || 1
# (log(C)-C*(C*C))-((C-C)-(X-X*cos(C+X))) || 1
# ((C-C)-C*(C*C))-((C-C)-(X-X*cos(X))) || 1
# log(log(C))-(log(X)-(X-X*cos(X))) || 1
# log(log(C))-(log(C)-(X-X*cos(C+C^2))) || 1
# ((C-C)-C*(C*X))-(log(log(C))-(X-(X-cos(X)))) || 1
# ((C-C)-(C-C*X))-(log(log(C))-(X-(X-cos(X)))) || 1
# ((C-C)-(C-C*C^2))-(log(log(C))-(X-X*(X*cos(X)))) || 1
# ((C-C)-C*cos(C))-(log(C)-(X-X*cos(X))) || 1
# ((C-C)-C*cos(C))-((C-C)-(C-(X-X*cos(X)))) || 1
# (X-C*cos(C))-((C-C)-(C-X*(X*cos(C)))) || 1
# (X-C)-((C-C)-(C-X*(X*cos(X)))) || 1
# (X-C)-(C*C-(C-X*cos(X))) || 1
# log(C)-(C*C-(C-C*(C*cos(C)))) || 1
# log(C)-(C*C-(C-(C-C*C^2))) || 1
# log(C)-(C*C-(log(C)-(C-C))) || 1
# log(C)-(C*C-(log(C)-(X-C*C^(C^2)))) || 1
# log(C)^(C*C-(log(C)-(X-C))) || 1
# (C-C)^(C*C-(log(C)-(X-C*X))) || 1
# log(C-C)-(C*C-(log(C)-(X-C*X))) || 1
# log(C)-(C*C-(log(C)-(X-X*X))) || 1
# (C-C)-(C*C-((log(C)-C)-(X-C))) || 1
# (C-C)-(C*C-(log(log(C))-(X-X*X))) || 1
# (C-C)-(C*C-((log(C)-C)-(X-X*X^4))) || 1
# log(C)-(C*C-(log(log(C))-(X-X*X^(C^2)))) || 1
# log(X)-(C*C-(log(log(C))-(X-X*X^4))) || 1
# log(X)-(C*C-((log(C)-C)-(X-X/X^(C^2)))) || 1
# log(X)-(C*C-((C-C)-(X-X*X^4))) || 1
# log(X)-(C*C-((C-C)-(X-X*X^(C^2)))) || 1
# log(C)-(C*C-((C-C)-(X-X/X^4))) || 1
# (X-C)-(C*C-(log(C)-(X-X*C^4))) || 1
# (X-C)-(C*C-(log(C)-(X-C*cos(C)))) || 1
# (X-C)-(C*C-(log(C)-(X-X*cos(X)))) || 1
# (X-C)-(C*C-(log(C)-(X-X*X^(X^2)))) || 1
# ((C-C)-C)-((C*C)*C-(log(log(C))-(X-X*X^(X^2)))) || 1
# ((C-C)-C)-(C*C-(log(C)-(X-X*X^(X^2)))) || 1
# (X-C)-(C*C-(log(C)-(X-X*X^2))) || 1
# ((C-C)-C)-(C*C-(log(log(C))-(X-X*X))) || 1
# ((C-C)-C)-((C*C)*C-((log(C)-C)-(X-X*X^4))) || 1
# ((C-C)-C)-((C*C)*C-(log(log(C))-(X-X*X^(C^2)))) || 1
# ((C-C)-C)-((C*C-C)-((log(C)-C)-(X-X/(C/X)^(C^2)))) || 1
# ((C-C)-C)-((C*C-C)-((log(C)-C)-(X-X*(C/X)^(C^2)))) || 1
# ((C-C)-C)-((log(C)-C)-((log(C)-C)-(X-X*X^(C^2)))) || 1
# ((C-C)-C)-((C*C-C)-((log(C)-C)-(X-X*X))) || 1
# ((C-C)-C)-((C*C-C)-((log(C)-C)-(X-X*X^(C^2)))) || 1
# ((log(C)-C)-C)-((log(C)-C)-((C-C)-(X-X*(C/C^2)))) || 1
# ((log(C)-C)-C)-((log(log(C))-C)-((C-C)-(X-(X-X/C^2)))) || 1
# ((log(C)-C)-C)-((log(log(C))-C)-((C-C)-(X-(X-C/C^2)))) || 1
# ((log(C)-C)-C)-((log(log(C))-C)-((C-C)-(X-X*(X/C^2)))) || 1
# ((log(C)-C)-C)-((log(C)-C)-((C-C)-(X-X*(X/C^2)))) || 1
# ((C-C)-C)-((log(C)-C)-((log(C)-C)-(X-X*(X/C^2)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((C-C)-(X-X*sin(X)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((log(C)-C)-(X-X*sin(X)))) || 1
# ((C-C)-C)-((log(C*C)-C)-((log(C)-C)-(X-(X-C/(C+C)^3)))) || 1
# ((C-C)-C)-((log(C*C)-C)-((C-C)-(X-X*C^((C+C)^3)))) || 1
# ((log(C)-C)-C)-((log(C*C)-C)-((C-C)-(X-(X-C/(C+C)^3)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((C-C)-(X-(X-C/(C+C)^3)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((C-C)-(X-X*sin(C)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((C-C)-(C-(C*(X/X))*C^((C+C)^3)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((C-C)-(X-(X*(X/X))*C^(C^3)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((log(C)-C)-(X-(X*(X/X))*C^(C^3)))) || 1
# ((C-C)-C)-((log(log(C))-C)-((log(C)-C)-(X-(C*(X/X))*C^(C^3)))) || 1
# ((C-C)-C)-((log(C*C)-C)-((log(C)-C)-(X-X*C^4))) || 1
# (X-C)-((log(C*C)-C)-((log(C)-C)-(X-X*C^4))) || 1
# ((C-C)-C)-((log(C*C)-C)-((log(C)-C)-(X-X/sin(C)))) || 1
# ((C-C)-(C-C*cos(C)))-((log(C)-C)-(log(log(C))-(X-X/sin(C+C)))) || 1
# ((C-C)-(C-C*cos(C)))-((log(C)-C)-((log(C)-C)-(X-X/sin(C+X)))) || 1
# ((C-C)-C)-((log(C)-C)-(log(log(C))-(X-X*(C+C)^4))) || 1
# ((C-C)-(C-C*X))-((log(C)-C)-(log(log(C))-(X-X*(C+C)^2))) || 1
# ((C-C)-(C-C*X))-((log(C)-C)-(log(log(C))-(X-X*sin(C/X)))) || 1
# ((C-C)-C)-((log(C)-C)-(log(log(C))-(X-X*(C/X)^4))) || 1
# ((C-C)-C)-((log(C)-C)-(log(log(C))-(X-X*X^4))) || 1
# ((C-C)-C)-((log(C)-C)-((log(C)-C)-(X-X*(C+X)^4))) || 1
# ((C-C)-C)-((log(C)-C)-((C-C)-(X-X*X^4))) || 1
# ((C-C)-C)-((log(C)-C)-((C-C)-(X-X*C^4))) || 1
# ((C-C)-C)-((log(C)-C)-((C-C)-(X-X*C^2))) || 1
